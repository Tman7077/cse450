# %% [markdown]
# ### Setup

# %%
# Import libraries

import contextlib
import gc
import io
import numpy as np
import os
import random
import re
import string
import time

import tensorflow as tf
from tensorflow.keras import Sequential # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D, StringLookup, TextVectorization # type: ignore

# NOTE: testing
# print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2025-03-20 01:52:39.007305: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-20 01:52:39.139210: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742457159.189067  459171 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742457159.204269  459171 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-20 01:52:39.329560: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
RESTART = True
EPOCH_TO_PICKUP = 0
PATH = ''
VOCAB_SIZE = 8192
SEQUENCE_LENGTH = 128
BATCH_SIZE = 64
BUFFER_SIZE = 10000
TEACHER_FORCED = False

# %% [markdown]
# ### Text Processing

# %%
def preprocess_text(text):

    # text = text.replace("Project Gutenberg", "")
    # text = text.replace("Gutenberg", "")

    # Remove carriage returns
    # text = text.replace("\r", "")

    # fix quotes
    text = text.replace("“", "\"")
    text = text.replace("”", "\"")

    # Replace any capital letter at the start of a word with ^ followed by the lowercase letter
    text = re.sub(r"(?<![a-zA-Z])([A-Z])", lambda match: f"^{match.group(0).lower()}", text)

    # Replace all other capital letters with lowercase
    text = re.sub(r"([A-Z])", lambda match: f"{match.group(0).lower()}", text)

    # Remove duplicate whitespace
    # text = re.sub(r"\s+", " ", text)
    # text = re.sub(r"\n+", "\n", text)
    # text = re.sub(r"\t+", "\t", text)

    # Replace whitespace characters with special words
    text = re.sub(r"(\t)", r" zztabzz ", text)
    text = re.sub(r"(\n)", r" zznewlinezz ", text)
    text = re.sub(r"(\s)", r" zzspacezz ", text)

    # Split before and after punctuation
    for punctuation in string.punctuation:
        text = text.replace(punctuation, f" {punctuation} ")

    return text

def postprocess_text(text):

    # Replace special words with whitespace characters
    text = text.replace("zztabzz", "\t")
    text = text.replace("zznewlinezz", "\n")
    text = text.replace("zzspacezz", " ")

    # Remake capital letters at beginning of words
    text = re.sub(r"\^([a-z])", lambda match: f"{match.group(1).upper()}", text)

    text = text.replace("^", "")

    return text

def getMyText(filename='all_talks.txt'):
    file_name = filename
    local_dir = 'saved_files'
    local_path = os.path.join(local_dir, file_name)

    try:
        # Ensure the directory exists
        if not os.path.exists(local_dir):
            os.makedirs(local_dir)

        # Check if the file exists locally
        if os.path.exists(local_path):
            print(f"File '{file_name}' found locally. Using it.")
        else:
            print(f"File '{file_name}' not found.")
            return

        # Read the file's contents
        with open(local_path, 'rb') as file:
            text = file.read().decode(encoding='utf-8')

        return preprocess_text(text)

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
if RESTART:
  vocab_text = getMyText()

  ### Make vocabulary (Adapted from TensorFlow word embedding tutorial)
  # Use the text vectorization layer to normalize, split, and map strings to
  # integers. Note that the layer uses the custom standardization defined above.
  # Set maximum_sequence length as all samples are not of the same length.
  vectorize_layer = TextVectorization(
      standardize='lower',
      split='whitespace',
      max_tokens=VOCAB_SIZE,
      output_mode='int',
      )
  # Make a text-only dataset (no labels) and call adapt to build the vocabulary.
  vectorize_layer.adapt([vocab_text])
  vocabulary = vectorize_layer.get_vocabulary()

  ### Save Vocabulary
  with open(PATH + "vocabulary.txt", "w") as file:
    for word in vocabulary:
        file.write(word + "\n")
else:
  ### Load Saved Vocabulary
  with open(PATH + "vocabulary.txt", "r") as file:
      vocabulary = [word.strip() for word in file.readlines()]
      vocabulary = vocabulary

  vectorize_layer = TextVectorization(
      vocabulary=vocabulary,
      standardize='lower',
      split='whitespace',
      max_tokens=VOCAB_SIZE,
      output_mode='int',
      )
  
# NOTE: testing
# print(vocabulary[:20])
# print(vocabulary[-20:])
# Out:
# File 'all_talks.txt' found locally. Using it.
# I0000 00:00:1742457189.913623  459171 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13499 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# This function will generate our sequence pairs:
def split_input_target(sequence):
    input_ids = sequence[:-1]
    target_ids = sequence[1:]
    return input_ids, target_ids

# This function will create the dataset
def text_to_dataset_teacher_forced(text, *args, **kwargs):
  
  all_ids = vectorize_layer(text)
  ids_dataset = tf.data.Dataset.from_tensor_slices(all_ids)
  del all_ids
  sequences = ids_dataset.batch(SEQUENCE_LENGTH+1, drop_remainder=True)
  del ids_dataset

  # Call the function for every sequence in our list to create a new dataset
  # of input->target pairs
  dataset = sequences.map(split_input_target)
  del sequences

  return dataset

def text_to_dataset_curriculum_learning(text, initial_seq_length=24, max_seq_length=SEQUENCE_LENGTH*2, growth_factor=1.05, current_epoch=0):
    """
    Implements curriculum learning by gradually increasing sequence length as training progresses.
    
    Parameters:
        text (str): The input text data.
        initial_seq_length (int): The starting sequence length.
        max_seq_length (int): The maximum sequence length.
        growth_factor (float): The rate at which sequence length increases per epoch.
        current_epoch (int): The current training epoch.
    
    Returns:
        tf.data.Dataset: The processed dataset with gradually increasing sequence length.
    """
    # Compute the sequence length dynamically based on the current epoch
    sequence_length = min(max_seq_length, int(initial_seq_length * (growth_factor ** current_epoch)))
    
    print(f"Using sequence length: {sequence_length} for epoch {current_epoch}")
    
    # Convert text to token IDs
    all_ids = vectorize_layer(text)
    ids_dataset = tf.data.Dataset.from_tensor_slices(all_ids)
    del all_ids

    # Create sequences with the dynamically determined length
    sequences = ids_dataset.batch(sequence_length + 1, drop_remainder=True)
    del ids_dataset

    # Create input-target pairs (teacher forcing still applies, but curriculum learning controls sequence length)
    dataset = sequences.map(split_input_target)
    del sequences

    return dataset


def text_from_ids(ids):
  text = ''.join([vocabulary[index] for index in ids])
  return postprocess_text(text)

def setup_dataset(dataset):
  dataset = (
    dataset
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE, drop_remainder=True)
    .prefetch(tf.data.experimental.AUTOTUNE))
  return dataset

# %%
if TEACHER_FORCED:
    learning_mode_fn = text_to_dataset_teacher_forced
else:
    learning_mode_fn = text_to_dataset_curriculum_learning

vocabulary_adjusted = vocabulary
vocabulary_adjusted[0] = '[UNK]'
vocabulary_adjusted[1] = ''
words_from_ids = tf.keras.layers.StringLookup(vocabulary=vocabulary_adjusted, invert=True)

if RESTART:
  vocab_ds = learning_mode_fn(vocab_text)
  for input_example, target_example in vocab_ds.take(1):
    print("Input: ")
    print(input_example)
    print(text_from_ids(input_example))
    print(words_from_ids(input_example))
    print("Target: ")
    print(target_example)
    print(text_from_ids(target_example))
    
  vocab_ds = setup_dataset(vocab_ds)
# Out:
# Using sequence length: 24 for epoch 0
# Input:
# tf.Tensor(
# [   3  169    2   37    5    2   19    2   13    2 2909    5    2 3558
#     2   21    2 1035    2  908    2 3379    2    9], shape=(24,), dtype=int64)
# Let us, for a minute, examine our leadership report card to
# tf.Tensor(
# [b'^' b'let' b'zzspacezz' b'us' b',' b'zzspacezz' b'for' b'zzspacezz' b'a'
#  b'zzspacezz' b'minute' b',' b'zzspacezz' b'examine' b'zzspacezz' b'our'
#  b'zzspacezz' b'leadership' b'zzspacezz' b'report' b'zzspacezz' b'card'
#  b'zzspacezz' b'to'], shape=(24,), dtype=string)
# Target:
# tf.Tensor(
# [ 169    2   37    5    2   19    2   13    2 2909    5    2 3558    2
#    21    2 1035    2  908    2 3379    2    9    2], shape=(24,), dtype=int64)
# let us, for a minute, examine our leadership report card to
# 2025-03-20 01:53:19.109745: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ### Model Building

# %%
# Create our custom model. Given a sequence of characters, this
# model's job is to predict what character should come next.
class ConferenceTextModel(tf.keras.Model):

  # This is our class constructor method, it will be executed when
  # we first create an instance of the class
  def __init__(self, vocab_size, embedding_dim, rnn_units):
    super().__init__()

    # Our model will have three layers:

    # 1. An embedding layer that handles the encoding of our vocabulary into
    #    a vector of values suitable for a neural network
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)

    # 2. A GRU layer that handles the "memory" aspects of our RNN. If you're
    #    wondering why we use GRU instead of LSTM, and whether LSTM is better,
    #    take a look at this article: https://datascience.stackexchange.com/questions/14581/when-to-use-gru-over-lstm
    #    then consider trying out LSTM instead (or in addition to!)
    self.lstm1 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
    self.lstm2 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
    self.lstm3 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)


    self.hidden1 = tf.keras.layers.Dense(embedding_dim*64, activation='relu')
    self.hidden2 = tf.keras.layers.Dense(embedding_dim*16, activation='relu')

    # 3. Our output layer that will give us a set of probabilities for each
    #    character in our vocabulary.
    self.dense = tf.keras.layers.Dense(vocab_size)

    ### Addition to default:
    # Define default initial states as None (they will be created once)
    self.initial_states = None

  ### Addition to default:
  def get_initial_states(self, batch_size):
    """Generate initial states once per batch"""
    return [
        [tf.zeros([batch_size, self.lstm1.units]), tf.zeros([batch_size, self.lstm1.units])],
        [tf.zeros([batch_size, self.lstm2.units]), tf.zeros([batch_size, self.lstm2.units])],
        [tf.zeros([batch_size, self.lstm3.units]), tf.zeros([batch_size, self.lstm3.units])],
    ]
  
  # This function will be executed for each epoch of our training. Here
  # we will manually feed information from one layer of our network to the
  # next.

  ### Original call():
  '''
  def call(self, inputs, states=None, return_state=False, training=False):
    x = inputs

    # 1. Feed the inputs into the embedding layer, and tell it if we are
    #    training or predicting
    # x = self.embedding(x, training=training)
    x = self.embedding(x, training=training)

    # 2. If we don't have any state in memory yet, get the initial random state
    #    from our GRUI layer.
    batch_size = tf.shape(inputs)[0]

    if states is None:
      states1 = [tf.zeros([batch_size, self.lstm1.units]), tf.zeros([batch_size, self.lstm1.units])]
      states2 = [tf.zeros([batch_size, self.lstm2.units]), tf.zeros([batch_size, self.lstm2.units])]
      states3 = [tf.zeros([batch_size, self.lstm3.units]), tf.zeros([batch_size, self.lstm3.units])]
    else:
      states1 = states[0]
      states2 = states[1]
      states3 = states[2]
    # 3. Now, feed the vectorized input along with the current state of memory
    #    into the gru layer.
    x, state_h_1, state_c_1 = self.lstm1(x, initial_state=states1, training=training)
    states_out_1 = [state_h_1,state_c_1]

    x, state_h_2, state_c_2 = self.lstm2(x, initial_state=states2, training=training)
    states_out_2 = [state_h_2,state_c_2]

    x, state_h_3, state_c_3 = self.lstm3(x, initial_state=states3, training=training)
    states_out_3 = [state_h_3,state_c_3]

    states_out = [states_out_1, states_out_2, states_out_3]

    x = self.hidden1(x,training=training)
    x = self.hidden2(x,training=training)
    # 4. Finally, pass the results on to the dense layer
    x = self.dense(x, training=training)

    # 5. Return the results
    if return_state:
      return x, states_out
    else:
      return x
  '''

  ### Modified call():
  def call(self, inputs, states=None, return_state=False, training=False):
    x = self.embedding(inputs, training=training)
    batch_size = tf.shape(inputs)[0]

    # Use pre-defined function to get initial states
    if states is None:
        states = self.get_initial_states(batch_size)

    # LSTM layers process input sequentially
    x, state_h_1, state_c_1 = self.lstm1(x, initial_state=states[0], training=training)
    states_out_1 = [state_h_1, state_c_1]

    x, state_h_2, state_c_2 = self.lstm2(x, initial_state=states[1], training=training)
    states_out_2 = [state_h_2, state_c_2]

    x, state_h_3, state_c_3 = self.lstm3(x, initial_state=states[2], training=training)
    states_out_3 = [state_h_3, state_c_3]

    states_out = [states_out_1, states_out_2, states_out_3]

    x = self.hidden1(x, training=training)
    x = self.hidden2(x, training=training)
    x = self.dense(x, training=training)

    return (x, states_out) if return_state else x

# %%
if RESTART:
  dataset = vocab_ds
  del vocab_text
  del vocab_ds
else:
  dataset = learning_mode_fn(getMyText())
  dataset = setup_dataset(dataset)

embedding_dim = 128
rnn_units = 512
model = ConferenceTextModel(VOCAB_SIZE, embedding_dim, rnn_units)

# NOTE: testing
# Verify the output of our model is correct by running one sample through
# This will also compile the model for us. This step will take a bit.
# for input_example_batch, target_example_batch in dataset.take(1):
#     example_batch_predictions = model(input_example_batch)
#     print(example_batch_predictions.shape, "# (BATCH_SIZE, sequence_length, VOCAB_SIZE)")

# %%
# NOTE: testing
# model.summary()

# %%
# Here's the code we'll use to sample for us. It has some extra steps to apply
# the temperature to the distribution, and to make sure we don't get empty
# characters in our text. Most importantly, it will keep track of our model
# state for us.

class OneStep(tf.keras.Model):
  def __init__(self, model, vectorize_layer, vocabulary, temperature=1):
    super().__init__()
    self.temperature=temperature
    self.model = model
    self.vectorize_layer = vectorize_layer
    self.vocabulary = vocabulary

    # Create a mask to prevent "" or "[UNK]" from being generated.
    skip_ids = StringLookup(vocabulary=list(vocabulary))(['', '[UNK]'])[:, None]
    sparse_mask = tf.SparseTensor(
        # Put a -inf at each bad index.
        values=[-float('inf')]*len(skip_ids),
        indices = skip_ids,
        # Match the shape to the vocabulary
        dense_shape=[len(vocabulary)])
    self.prediction_mask = tf.sparse.to_dense(sparse_mask,validate_indices=False)

  @tf.function
  def generate_one_step(self, inputs, states=None):
    # Convert strings to token IDs.
    input_ids = self.vectorize_layer(inputs)

    # Run the model.
    # predicted_logits.shape is [batch, char, next_char_logits]
    predicted_logits, states =  self.model(inputs=input_ids, states=states,
                                          return_state=True)
    del input_ids
    # Only use the last prediction.
    predicted_logits = predicted_logits[:, -1, :]
    predicted_logits = predicted_logits/self.temperature

    # Apply the prediction mask: prevent "" or "[UNK]" from being generated.
    predicted_logits = predicted_logits + self.prediction_mask

    # Sample the output logits to generate token IDs.
    predicted_ids = tf.random.categorical(predicted_logits, num_samples=1)
    del predicted_logits
    predicted_ids = tf.squeeze(predicted_ids, axis=-1)

    # Return the characters and model state.
    return words_from_ids(predicted_ids), states

# %%
def produce_sample(model, vectorize_layer, vocabulary, temp, epoch, prompt, length=200, do_print=True):
  one_step_model = OneStep(model, vectorize_layer, vocabulary, temp)
  states = None
  next_char = tf.constant([preprocess_text(prompt)])
  result = [tf.constant([prompt])]

  for _ in range(length):
    next_char, states = one_step_model.generate_one_step(next_char, states=states)
    result.append(next_char)

  result = tf.strings.join(result)
  if do_print:
    print(postprocess_text(result[0].numpy().decode('utf-8')))
    print('Epoch: ' + str(epoch) + '\n', file=open(PATH + 'tree.txt', 'a'))
    print('Temp: ' + str(temp) + '\n', file=open(PATH + 'tree.txt', 'a'))
    print(postprocess_text(result[0].numpy().decode('utf-8')), file=open(PATH + 'tree.txt', 'a'))
    print('\n\n', file=open(PATH + 'tree.txt', 'a'))
    del states
    del next_char
    del result
  else:
    return postprocess_text(result[0].numpy().decode('utf-8'))

# %% [markdown]
# ### Model Training

# %%
if RESTART == False:
  model.load_weights(PATH + "models/conf-test2-400ep.keras")

# %%
early_stop = EarlyStopping(
    monitor='loss',
    min_delta=0.002,
    patience=10,
    restore_best_weights=True
)
loss = tf.losses.SparseCategoricalCrossentropy(from_logits=True)
LEARNING_RATE = 0.002
opt = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=opt, loss=loss)

### NOTE:
# Look into learning rate more (& decay?)
# Set learning rate based on if transfer learning or not

base_epochs = 200
transfer_epochs = 0
num_epochs_total = base_epochs + transfer_epochs
main_test_num = 4
transfer_test_num = 2
if TEACHER_FORCED:
    learn_type = 'teacher'
else:
    learn_type = 'curric'

if RESTART:
  start_epoch = 0
else:
  start_epoch = EPOCH_TO_PICKUP

# %%
def run(name='all_talks'):
  stop_training = False
  for e in range(start_epoch, num_epochs_total):
    if stop_training:
      print(f"Early stopping triggered at epoch {e}. Exiting training.")
      break
    success = False
    while(success == False):
      try:
        print(f'epoch: {e + 1}/{num_epochs_total}')
        new_text = getMyText(f'{name}.txt')
        dataset = learning_mode_fn(new_text, current_epoch=e)
        del new_text
        dataset = setup_dataset(dataset)
        model.optimizer.learning_rate.assign(LEARNING_RATE*(0.99**e))
        model.fit(dataset, epochs=1, verbose=1, callbacks=[early_stop])
        if early_stop.stopped_epoch > 0:
          stop_training = True
        print("finished training...")
        del dataset
        for temp in [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]:
          produce_sample(model, vectorize_layer, vocabulary, temp, e, 'As a disciple of Jesus Christ, I testify')
        print("samples produced...")
        gc.collect()
        print("garbage collected...")
        tf.keras.backend.clear_session()
        print("session cleared (to save memory)...")
        success = True
      except:
        gc.collect()
        tf.keras.backend.clear_session()
        try:
          del dataset
        except:
          print("dataset already deleted")
        print("retrying epoch: " , e)

  print(f'Final epoch ({num_epochs_total}) reached.')
  filename = f'models/conf-t{main_test_num}-{base_epochs}e_{learn_type}'
  if base_epochs < num_epochs_total:
    filename += f'_{name.split("-")[-1]}-t{transfer_test_num}-{transfer_epochs}e'
  filename += '.keras'
  model.save(filename)
  print(f"Model saved as {filename}")

# %%
run() # just once, for training from scratch
# Out:
# epoch: 1/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 24 for epoch 0
# I0000 00:00:1742457304.897278  460334 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 4966/4966 ━━━━━━━━━━━━━━━━━━━━ 348s 70ms/step - loss: 2.7488
# finished training...
# As a disciple of Jesus Christ, I testify of the Savior Jesus Christ, we must be saved, we will be a loving Father in His Son. Jesus Christ, is the Savior of Israel and His Atonement. The Lord has said that the Savior is the Savior and His Atonement, and His Atonement is not surprising that we are not accountable to God.
#  I know that we are not careful to be blessed with the Lord’s Church and to the Church. The Lord said, "I know that the
# As a disciple of Jesus Christ, I testify that His Atonement is not surprising that the gospel of Jesus Christ is the Lord and His Son, Jesus Christ, who holds the gospel of Jesus Christ and be added to the Savior’s Atonement. We are grateful for the priesthood and auxiliary leaders and of the ward and ward presidencies. The Lord promised that "the Lord hath commanded in heaven to his people, and the Lord shall be accomplished in heaven."
#  The Savior said, "The Lord said unto you, Verily I
# As a disciple of Jesus Christ, I testify that the Lord lives. He is the Son of God. In the name of Jesus Christ, amen.
#
#  We must be a blessed of a personal spiritual and spiritual revelation that we are to help us in the work of the Church, and we are preparing for the Lord’s gospel.
#  We are not careful to be confused with the Lord in His children. The Lord said they had been able to come to the Philippines Samoa, he had never been less. He had emphasized
# As a disciple of Jesus Christ, I testify that what is with the Atonement of Jesus Christ, we will be contrary to the gospel, as we live the gospel. I bear witness that the Lord liveslivesand that He livesis that Jesus Christ is our Savior and Savior Jesus Christ. In this way, there is a vision of life in the Book of Mormon inconsistent with the Book of Mormon. There were the Prophet Joseph Smith had sought his mission, President Nelson has provided in the gospel, the Savior emphasized that
# As a disciple of Jesus Christ, I testify of the Savior, … I am the Lord my God." (1 Ne. 2:26; D&C 42:14). For all members of the Church, this is true for whom revelation is especially as a safe with the priesthood with His children, and we will be accepted and to be righteous to our Father in Heaven is necessary to live.
#  In a process, a Christlike word, you will not feel but wish to tell the Church and become more. It also explains that the
# As a disciple of Jesus Christ, I testify to you, in the name of Jesus Christ, amen.
#
#  Remember this question:
#  - Logic of Sunday morning I must still go to Japan in Brigham City, President David C. Smith, President Kimball departed a young couple in the missionaries who had lost the mortal companion. Lehi was in his team was the wife of Utah.
#  The Savior taught that he testified. He is a living mother, and helped against the word and saving ordinances of this gospel.
#  Alma
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 2/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 25 for epoch 1
# 4775/4775 ━━━━━━━━━━━━━━━━━━━━ 334s 70ms/step - loss: 2.1659
# finished training...
# As a disciple of Jesus Christ, I testify that Jesus is the Christ, the Son of the living God, and that I am God who has repented of his sins and is the Son of God." The Savior taught that "the Lord will be our Father in Heaven, and I will give unto you the name of God the Lord Jesus Christ and the Savior of the world."
#  This is the Atonement of Jesus Christ, we are taught that the Savior was the Christ. The Church of Jesus
# As a disciple of Jesus Christ, I testify of Jesus Christ. Amen.
#
#  A few years ago I was a teenager when I was serving as bishop of the Church and a mission president in the Church and the Church to be a General Authority Seventies, I am grateful for the love of this President Russell M. Nelson as President of the Church. He is the Light of the world. I have read the Book of Mormon as the Prophet Joseph Smith and Oliver Cowdery and the Apostles
# As a disciple of Jesus Christ, I testify that Jesus is the Christ. This is the sacred nature of all the people of the world. The Lord has said to the Prophet Joseph that "wickedness never was happiness." It has a powerful privilege to serve as a Church leader.
#  The Church is a remarkable example of the Church and the Church of Jesus Christ. The Lord has said, "And I will impart unto you the Eternal Father, and I will give you rest upon your souls, that ye may be
# As a disciple of Jesus Christ, I testify of Him the Lord Jesus Christ, is to bless all people.
#  I am grateful for all of women who will be regularly ordained by the heads of the Twelve, and we have been assigned to preside over the Church and the Melchizedek Priesthood and other authorities. They watched the hymns of Zion were the following Church Internet and temporary status in the United States on September 3, 1836. It was the First Presidency and Quorum of the Twelve Apostles and Relief Society sisters.
# As a disciple of Jesus Christ, I testify of the Church and the Restoration of the gospel of Jesus Christ.
#  I have had a profound apostolic privilege to speak to those who have been saved, had been taught to all of the women of the Primary General Handbook of Great Price, missionaries in Chicago and Canada, and the Young Women classes in the United States, and the Church is restored in the West. My father replied that an this meaning was time in the Church but I have been discouraged about the social
# As a disciple of Jesus Christ, I testify that Jesus is the Christ, amen.
#
#  We know that here and still was President Hinckley.
#  His friends of the Western Samoa been a home evening, a navy of devoted Relief Society leaders and their clergy in her hand with much respect for their great-grandfather, was raised in me on this subject and, on the foundation of their life, serving the Prophet, Jesus Christ. In a deep, scripture discernment was brought forth as "the blood of the marriage, or the cords of the
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 3/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 26 for epoch 2
# 4598/4598 ━━━━━━━━━━━━━━━━━━━━ 323s 70ms/step - loss: 2.0343
# finished training...
# As a disciple of Jesus Christ, I testify of Jesus Christ, the Son of God. He is the Son of God, the Savior of the world. He is our Savior, our Redeemer. He is the Light and Life of the World Jesus Christ. This is the Church of Jesus Christ. In the name of Jesus Christ, amen.
#
#  I bear witness of the Spirit of the Lord in the name of Jesus Christ, amen.
#
#  The Savior Himself was "the Son of
# As a disciple of Jesus Christ, I testify of the Atonement of Jesus Christ to the world. I have been in Spanish, I was a Latter-day Saint. It was a great man named Joseph Smith to the Romans. He was the Savior of the world, He was a God, and the Redeemer of the world. He was a prophet of God. He was a Prophet of the Restoration. He said that I was called to be a prophet and a prophet in the Book of Mormon as a member
# As a disciple of Jesus Christ, I testify in the name of Jesus Christ, amen.
#
#  We are grateful that we have the Spirit of the Lord to guide the lives of all mankind. This is the first principle. He is the Savior. In the name of Jesus Christ, amen.
#
#  We are to be a Latter-day Saint, and the Savior Himself has been restored to the world. This is the authority of His Church.
#  He has a promise in the name of Jesus Christ.
#
# As a disciple of Jesus Christ, I testify that Jesus is the Christ, the Son of God, the Son of God, the Prince of Peace, the Son of God, that in the name of Jesus Christ, amen.
#
#  It is my purpose to share the gospel with each of us and our families. In the name of Jesus Christ, amen.
#
#  While we are not careful, we are concerned about the Lord for the Lord and His Atonement. I bear testimony that God lives, that Jesus
# As a disciple of Jesus Christ, I testify of the Savior of the world. He was an example of a Christ, a divinely appointed calling in the body of God. In the name of Jesus Christ, amen.
#
#  This I bear witness. In the name of Jesus Christ, amen.
#
#  I love you. I testify of the privilege of being in the Lord’s Kingdom, the Lord will help and protect us from the world. The United States assignment, and I was surprised to see and to a member
# As a disciple of Jesus Christ, I testify that I love the Aaronic Priesthood and sublime teachings of the Lord Jesus Christ as a Savior? That is why the Savior’s Atonement would be received to preserve the doctrine, by revelation for the Savior, or who is choosing a family or by family, as we can be faithful together, and unless we are truly not well pleased." (D&C 56:66.)
#  The Lord Himself lamented that he offered this revelation:
#  "Behold, I say unto you, thou hast no more than these
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 4/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 27 for epoch 3
# 4434/4434 ━━━━━━━━━━━━━━━━━━━━ 313s 70ms/step - loss: 1.9483
# finished training...
# As a disciple of Jesus Christ, I testify of the truth of the Father and the Son, the Savior of the world. I know that Jesus is the Christ. He is our Savior. We are His children and His children. We need to be true disciples of Christ and keep His commandments and follow His Son, Jesus Christ. We know that the Lord lives and guides us to follow Him and follow His Son, Jesus Christ, and His Son, Jesus Christ. In the name of Jesus
# As a disciple of Jesus Christ, I testify that the Lord has provided that we will be united in the work of the Lord.
#  President Russell M. Nelson, President Russell M. Nelson, has taught that "the Lord has provided a way for us to be saved and never will be saved." The Savior has given us the Savior’s Atonement to all the world. The Savior taught that He is the Son of God, the Lord Jesus Christ. In the Church we are blessed to be worthy to receive the
# As a disciple of Jesus Christ, I testify that the Atonement of Jesus Christ is a personage of spirit and that the Savior taught that our Savior is our Savior, our Redeemer and Savior of the world. That is a very hard time for all of us to make choices and priorities in our day. We are also grateful for the Savior’s power to help us prepare for our day. We should be more righteous and best for both the Savior and His Atonement.
#  The Savior explained that He had endured our mortal sins all
# As a disciple of Jesus Christ, I testify that the Savior is our Savior, our Advocate with the Father and His Son, our Lord and Savior, Jesus Christ. This is the testimony of Jesus Christ. I bear witness of Jesus Christ in the name of Jesus Christ, amen.
#
#  The scriptures teach us that the Church is organized only in English and the Restoration of the gospel of John.
#  We also know that the Savior’s Atonement is a powerful perspective for all of us. It is also
# As a disciple of Jesus Christ, I testify that Jesus is the Christ and Redeemer of the world. His Atonement and His redemptive mission in Luke  section of the Doctrine of The Church of Jesus Christ of Latter-day Saints is comprehensive, and surely one of the speakers is His miracles. Some are upset with a standard of choice. But we cannot be deceived. The answer is the same for all young people to avoid pornography and schedules under the bondage of the adversary. The Savior fulfills the Atonement of Christ, and
# As a disciple of Jesus Christ, I testify that God lives. I bear testimony of Him our Heavenly Father and Jesus Christ. He will bring you closer to Him. You love and know you are praying for and bless you.
#  When you understand what he said about the company was I’m in a second meeting, President Marion D. Kimball declared. "Often enough man were old but gently considered her husband but not know the home for their money.
#  He was thus told Corianton about the Savior’s Resurrection, and They came
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 5/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 29 for epoch 4
# 4139/4139 ━━━━━━━━━━━━━━━━━━━━ 294s 71ms/step - loss: 1.8744
# finished training...
# As a disciple of Jesus Christ, I testify that Jesus is the Christ, that He lives. I know that Jesus is the Christ. I know He lives. I know He lives. I know that Jesus is the Christ. I know that Jesus is the Christ. I know He lives. I know He lives and loves us and wants us to be His children. In the name of Jesus Christ, amen.
#
#  I bear witness of the Savior and His servants who have been ordained to the offices
# As a disciple of Jesus Christ, I testify that the Savior lives. I know that Jesus is the Christ, that I am God and that I am God, that I am the Son of God, that I am the Son of the living God" (John 3:8).
#  The Savior taught that if we follow His example and His teachings, we will be protected by the Savior’s atoning power to guide us in our own way. We can become one in the presence of our Father in Heaven and His
# As a disciple of Jesus Christ, I testify of Jesus Christ, that I am the Son of God. I know that Jesus is the Christ. I bear witness that Jesus is the Christ. I know that Jesus is the Christ, that I am our Redeemer, our Redeemer. The Savior lives. He is our Redeemer. I know that Jesus is the Christ, that I am God the Father and that I am come that I am God."
#  We are also privileged to have the Aaronic
# As a disciple of Jesus Christ, I testify of Him in the name of Jesus Christ, amen.
#
#  Some of you who are born in a world where you will avoid the same opposition that could be made in our modern world. When we sing members that are not yet in the service of others, it is my conviction that the Lord would have us do that.
#  When I was 12 years old, I sat next to my wife and the mother Joseph Smith. He was able to have the Relief Society president in
# As a disciple of Jesus Christ, I testify of Him and to their children. I testify that the Spirit of Christ is given to every man, that he may know good from evil; wherefore, ye shall know with a sincere heart, with real intent, having faith in him, then is a body of flesh and blood and that the whole earth shall be added upon [us], as we all do his will, for we shall be able to withstand the evil day."
#  We can yield to the end of our sins, our natures will be better through
# As a disciple of Jesus Christ, I testify of the divinity of Jesus Christ and of His Atonement. I have felt that revelation to our Father in Heaven’s plan of salvation.
#  We are promised that when Alma, John, Abraham come forth in the Final Judgment, we will be governed in our day, and we feel that our sins make of us happiness, subject to peace, happiness, and peace that surround us? We should both live and grow. The things we hope our Father in Heaven is that each of us can change our
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 6/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 30 for epoch 5
# 4005/4005 ━━━━━━━━━━━━━━━━━━━━ 285s 71ms/step - loss: 1.8179
# finished training...
# As a disciple of Jesus Christ, I testify that Jesus is the Christ, that this is His Church, and that He directs this Church, His Church, and His restored gospel. This is His Church. I testify of Jesus Christ, our Savior, and Savior, Jesus Christ, and our Savior Jesus Christ, who is our Savior and Redeemer, Jesus Christ. We know His Son, Jesus Christ, that He is our Savior, our Savior, our Lord, our Savior, our Redeemer, our Savior
# As a disciple of Jesus Christ, I testify that He lives. I testify of Jesus Christ, the Son of God, our Savior, our Redeemer, our Lord, our Savior. I know it is by the Holy Ghost, that I know that Jesus is the Christ, that I know that Jesus is the Christ, the Son of the living God, the Savior and the Holy Ghost, and the Holy Ghost shall be thy constant companion, and thy scepter an unchanging scepter of righteousness and truth; and thy dominion shall be
# As a disciple of Jesus Christ, I testify that He lives. I know His Son, Jesus Christ, who loves us, and that Jesus is the Christ, that Latter-day Saints can be examples of the Savior’s Atonement. The Savior emphasized that He "which is a personage of Spirit, and a personage of spirit[God] is the light and the life of the world" (D&C 121:37).
#  We know that the Church is true. We have the opportunity to have a testimony of the Savior and His
# As a disciple of Jesus Christ, I testify that Jesus is the Christ, that we are willing to obtain the highest degree of glory, for there is a constant peace in Christ that is the same?
#  "There is no more important way to describe the Lord’s work in the Church. We are the Latter-day Saints, and they could not be led astray by the Lord. We know who we are and what is the praise of the world. We are in the Lord’s house. We are united as to the Father and risen and
# As a disciple of Jesus Christ, I testify of Jesus Christ and His doctrine. This is my humble testimony to you that we are His children. For the Lord’s Son Jesus Christ, we have the seed, the Lord will direct and sustain all of His children. Our faith is emphasized by the Holy Ghost. This possibility is the key of the Restoration. In addition, our theology is to find levels of our religion and escape this possibility?
#  We encourage each of us to preserve the work of the Lord.
#  I
# As a disciple of Jesus Christ, I testify of Jesus Christ, who has promised that we will all have His Spirit to be with us, and we will be better worthy of our ancestors, including the Lord’s use of life’s consequences. Latter-day Saints are entitled to a Christian life. Family and friends hold a plan of God. The channels of revelation are provided under divine authority, the temple functions, and confirmation it will be fulfilled as we study the restored gospel of Jesus Christ. The inspired guidance made at the Quorum of the Twelve
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 7/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 32 for epoch 6
# 3762/3762 ━━━━━━━━━━━━━━━━━━━━ 270s 72ms/step - loss: 1.7621
# finished training...
# As a disciple of Jesus Christ, I testify of Jesus Christ, the Savior of the world, is the Son of God. He is the Son of God, Jesus Christ, the Savior of the world, is a great example. He is our Father. He is our Father, that He is our Savior, our Redeemer. He is our Savior, our Redeemer, and our Redeemer, and our Redeemer, and I testify of Him, in the name of Jesus Christ, amen.
#
#  I have been privileged to
# As a disciple of Jesus Christ, I testify of Him and His Atonement. I know that as I have done here, I will be a witness of the Spirit.
#  The Lord said, "If ye will enter in by the way, and receive the Holy Ghost, it will rise with you in the name of Jesus Christ. Amen."
#  The Lord said, "I will give unto you a commandment, that the fulness of my gospel might be proclaimed by the weak and the simple unto the ends of the world."
#
# As a disciple of Jesus Christ, I testify to you that this is the Lord’s work, and I know His Son, Jesus Christ, is our Savior and Redeemer of the world.
#  The Lord said that "gender is an essential characteristic of individual premortal, mortal, and eternal identity and purpose."
#  The Savior said, "I will give unto the children of men in my name they shall not know who I am, they will not know who I am, because my name is I myself.
#  "And now, O Father
# As a disciple of Jesus Christ, I testify to you that it is true and that the Lord loves us, and He has said, "This is My Beloved Son. Hear Him!"
#  The Book of Mormon is a clear evidence of the fulfillment of the prophecy when He said:
#  "[The Lord] maketh their garments upon them, that they might have joy" (2 Nephi 28:20).
#  I testify of the divinity of Jesus Christ and the truthfulness of the gospel of Jesus Christ and the future have been taught
# As a disciple of Jesus Christ, I testify of the certainty that God has endowed us for the example of the Savior, the Redeemer. He is our Savior, and He is our Father. He is our Savior, our Redeemer, our Healer, our Lord, our Savior. This will be our Father in Heaven. I will conclude with the approval of His Holy Spirit as he is under the direction of the President.
#  It is inspiring to say that a faithful young man offended and expected sufficient health. We were commanded
# As a disciple of Jesus Christ, I testify of this Savior, who is our Savior, we rejoice in what we cannot restore. The Lord said, "Touch not [and] not faint, for he that hath seen me hath seen the command, he that hath seen me hath seen the temptation of the children of men?
#  "Rejoice, and be exceeding glad: for my strength doth go and where thou would ask the Father, but by me. …
#  "Now, I care not to come into the world with my God.
#  "For my yoke
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 8/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 33 for epoch 7
# 3652/3652 ━━━━━━━━━━━━━━━━━━━━ 265s 72ms/step - loss: 1.7157
# finished training...
# As a disciple of Jesus Christ, I testify of Jesus Christ, our Savior, and our Redeemer. I was promised that the Savior would take the Atonement of Jesus Christ with His disciples and His Atonement.
#  When I was a young man, I was privileged to visit the Saints in England. He was a very old man. He had been awakened and disappointed at the Savior’s betrayal and the Crucifixion of Christ. He was a God who was the Jehovah. He was a prophet of God. He was a
# As a disciple of Jesus Christ, I testify of Him. I testify of Him and our Heavenly Father. I know that He loves us. He is our Father. He is our Redeemer. I know that Jesus Christ lives and loves us and is our Savior. His Son, Jesus Christ, is the Savior and Redeemer of the world. This is His work, and the Atonement of Jesus Christ includes "the Holy Ghost" (D&C 46:5).
#  The Savior taught that we should "always retain
# As a disciple of Jesus Christ, I testify of Jesus Christ, whom the Lord has established, and the Holy Ghost is a personage of spirit. I testify of him, who is the Light and Life of the World. It is our solemn responsibility to follow the Savior and His Atonement. Because of His sacrifice, He has promised us all of us to be worthy of the Light of Christ. We are promised that "if ye shall press forward, feasting upon the word of Christ, and endure to the end."
#  I
# As a disciple of Jesus Christ, I testify of Jesus Christ and His restored gospel. As a result of the Atonement of Jesus Christ, the Savior established His Church to help us prepare for exaltation and exaltation. We have the agency and joy of our life in this life and what we have to be and what we have already endured.
#  Moral values are called by the Holy Ghost to guide us into this life. We must not ignore His teachings. We are to be obedient to His commandments. We seek to follow
# As a disciple of Jesus Christ, I testify of his mission and His gospel and Jesus Christ, amen.
#
#  As a young man, I saw what his record came when the Book of Mormon was written to restore the patriarchal blessing, marriage and in the Aaronic Priesthood. Time after time, Joseph Smith declared that "the spirits of the dead should be glad in the land of the high ground, and men’s hands were raised and the patriarch and the country of all the Nephites in the Americas.
#  The Book of Mormon:
# As a disciple of Jesus Christ, I testify of Jesus Christ, whose Atonement makes it all possible. Love of Jesus Christ creates the unseen feelings of love. We learn from the Holy Ghost that that faith had merit a remission of their sins that almost others will be blessed in all the plans they have committed in each world in response to this commitment. Over from years of preparation, in large numbers, in the home and family, the role of families and families in mortality is the time for men to prepare for their duties. In their administrative
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 9/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 35 for epoch 8
# 3449/3449 ━━━━━━━━━━━━━━━━━━━━ 254s 73ms/step - loss: 1.6647
# finished training...
# As a disciple of Jesus Christ, I testify that Jesus is the Christ, the Son of God, the Only Begotten of the Father, and the Son of God the Father and the Son and the Holy Ghost.
#  The Lord said, "If ye are not one ye are not mine" (D&C 88:124).
#  We are not to be free from the evils of the world.
#  The Church is a refuge from the storm. It is a great challenge to all of us. We are blessed to have
# As a disciple of Jesus Christ, I testify that He lives, that Jesus is the Christ, that the gospel of Jesus Christ is true. I know that the Savior lives. I know He lives, and I know He lives. I know He lives. In the name of Jesus Christ, amen.
#
#  Our primary emphasis on the family proclamation is a vital part of the plan of salvation. The Savior said, "I will not leave you comfortless: I will come to you."
#  We know from the scriptures that
# As a disciple of Jesus Christ, I testify that He lives. I know He lives. In the name of Jesus Christ, amen.
#
#  I am grateful to be with you on this sacred occasion to meet with the Quorum of the Twelve Apostles in our time.
#  I bear witness of Jesus Christ, our Savior and Redeemer, and our Savior, Jesus Christ, was not the first President of the Church and that he was an officer in the Church in Europe in New Zealand, where he was a member
# As a disciple of Jesus Christ, I testify in the name of Jesus Christ, amen.
#
#  We are to "live in faith, and be loyal to one another, and to serve one another" (Moro. 7:45–46).
#  The Savior foresaw that the reality of repentance is a Father in Heaven who loves us! He knows us, and He knows why we expect to be welcomed to Him and His Beloved Son Jesus Christ. We should do so and joyfully connect ourselves to Him and be anxious to obey. He knows
# As a disciple of Jesus Christ, I testify that we are willing to walk uprightly before the Lord.
#  If he will give me a single young woman as a friend, I will share these thoughtful experiences in our Church meetings and sacrament meetings in English and South America; their friends were picking and even destroyed.
#  We were serving in Argentina, we could turn the stage and introduce those who had been parents of widows and boys who had not served to preserve their family and their employment, they made fun of them. He was a very old
# As a disciple of Jesus Christ, I testify that the Father and the Son have glory of the telestial law, to be the supreme desire and judgment of our Heavenly Father also.
#  Think about this occasion. I attended from the new box in California, and just six miles from Washington to rest in the Air Force ‘South Tower. I do not believe I was old enough to have a meeting. But the scripture was 100 percent, and it appeared, to take his family into a united room. When he wasn’t going to deliver his
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 10/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 37 for epoch 9
# 3267/3267 ━━━━━━━━━━━━━━━━━━━━ 241s 74ms/step - loss: 1.6204
# finished training...
# As a disciple of Jesus Christ, I testify that He lives. I know that Jesus is the Christ. I know that He lives. I know that Jesus is the Christ, the Son of God, the Only Begotten of the Father, the Only Begotten of the Father in the flesh. He is our Savior and Redeemer, who is Christ, the Son of God, that I was crucified for the sins of the world, to bear the sins of the world, to be redeemed, and to suffer for all men that
# As a disciple of Jesus Christ, I testify that He lives. I know that. I know that. I know that Jesus is the Christ. I know that He lives. I know that Jesus is the Christ. I know that He lives. I know He lives. I know that Jesus is the Christ, the Son of God, the Messiah, the Son of God. He is our Savior and Redeemer, who is the Son of God, that He is the Son of the living God. I
# As a disciple of Jesus Christ, I testify that Jesus is the Christ, that He is our Savior and Redeemer. I know that He lives! Jesus is the Christ. He is our Redeemer and our Redeemer, our Savior. This is His Church. This is His church. He is the Son of God, that He lives, that Jesus is the Christ, that He loves us and that He is our Lord, our Redeemer, and our Redeemer. I bear witness that Jesus is the Christ and that
# As a disciple of Jesus Christ, I testify that Jesus is the Christ, the Son of the Living God. I testify that we have children of the covenant, and they are the most desirable of all the gifts of God."
#  Following baptism, family proclamation, we have a responsibility and responsibility to strengthen our family, and we know from our words, and we want to follow the example of the Savior, who said, "Be of good cheer, and do not fear, for I the Lord am with you, and will stand by you."
# As a disciple of Jesus Christ, I testify of that as Paul declared that when we "take upon [us] the name of [Jesus] Christ, [and] show unto [ourselves] all things to [our] remembrance" (Moroni 10:39).
#  In addition to knowing that others are a part of our testing, our claim will be over the years. Our need for this cleansing power is that we are all children of a Heavenly Father.
#  When we speak plainly about one of the most important moral things that we can do and extra in mortality,
# As a disciple of Jesus Christ, I testify with all my heart as an Apostle for our own lives.
#  Question: Have your faith been securely upon,
#  I shall see him in thy bosom.
#  Before the end of hell, behold, it shall rise again in the arms of mortal iniquity.
#  "For verily, verily I say unto you, they shall not be moved out of their place.
#  "And they shall also teach their children to pray, and to walk uprightly before the Lord" (Matthew 16:12).
#  He stated: "
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 11/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 39 for epoch 10
# 3104/3104 ━━━━━━━━━━━━━━━━━━━━ 231s 74ms/step - loss: 1.5745
# finished training...
# As a disciple of Jesus Christ, I testify that He lives. I know His voice and His name and His Son, Jesus Christ, and His Atonement, I testify that He will bless and sanctify our souls and sanctify us (see Alma 5:24).
#  The Book of Mormon teaches that "the Lord said unto Enoch: Go forth and be saved" (D&C 4:3).
#  The Savior taught that we should "remember in all things the things of this world" (D&C 58:27).
#  The
# As a disciple of Jesus Christ, I testify of the truth of these things in the name of Jesus Christ, amen.
#
#  When you are young, you are the Lord’s agent. You are the presiding high priest of the ward as an Apostle. I am grateful for the Lord’s message to the world that we will be called to this session of conference with respect to the members of the Church, the Relief Society, the Young Women, and the Primary organizations in the Church. I believe that the Lord has a way of
# As a disciple of Jesus Christ, I testify of Jesus Christ, our Redeemer, and our Redeemer. The Savior taught us to "do not act in all holiness before me;
#  "And he shall go forth," he said, "and the door shall be opened unto [his] people" (D&C 46:18–19).
#  It is known that the Prophet Joseph Smith was a prophet of the Restoration of the gospel of Jesus Christ, and he was betrayed on the other side of the veil."
#  In the Book of Mormon we
# As a disciple of Jesus Christ, I testify of the power of the Atonement of Jesus Christ, the Atonement of Jesus Christ, and in the Holy Ghost? "Thou shalt have no other name known to me by the mouth of my servants, and by the ministering of angels, and by mine own voice, and by the voice of me, and unto you he will give you a promise, that you may bear them "till you seek for yourselves what God hath prepared for them that love him" (Ps. 46:10).
#  The Savior promised
# As a disciple of Jesus Christ, I testify that as a prophet of God, I ask the Lord for the blessings we have received in that calling. The Lord’s answer is brief. "For where is my name, and my word shall be in my name, that ye may be sanctified by the reception of the Holy Ghost, that ye may stand spotless before me at the last day. …
#  "But whatsoever ye shall do, ye shall do it in my name.
#  "And my grace shall attend you, that you may be instructed more perfectly
# As a disciple of Jesus Christ, I testify to you that "peaceable followers of Christ love Jesus Christ and repent need to be a Book of Mormon to my wife, Ruby, and my wife. She told me the entire world was that I knew I was dead who had made a correction. I’m sure that my words were true. The Saints disappeared in the Salt Lake Valley in New England, was determined as few other ordinary women did in the darkness, particularly to the Saints in Jerusalem. The Lord said, "If
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 12/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 41 for epoch 11
# 2956/2956 ━━━━━━━━━━━━━━━━━━━━ 223s 75ms/step - loss: 1.5323
# finished training...
# As a disciple of Jesus Christ, I testify of the power of the Atonement of Jesus Christ and the power of the Savior’s Atonement. I testify of Him and invoke His blessings upon you, our beloved young friends, in the name of Jesus Christ, amen.
#
#  I bear witness that God lives, that Jesus is the Christ, the Son of God. He is our Savior, our Redeemer. I testify of His divinity and the reality of His Atonement, and His atoning sacrifice for us.
#  I testify of
# As a disciple of Jesus Christ, I testify of the power of the Atonement of Jesus Christ. You can be a little more like that someone who has been not yet fully cared for and where they are going.
#  In Lehi’s vision of the Savior’s Atonement, Jesus said, "I am the resurrection, and the life: he that believeth in him, though he were dead, yet shall he live: And whosoever liveth and believeth in me shall never die."
#  The Prophet Joseph Smith taught that Jesus Christ "will be a personage of
# As a disciple of Jesus Christ, I testify of Jesus Christ, whose teachings and example are based on the gospel of Jesus Christ and its importance in God’s plan of happiness. It is a spiritual death. It is a pillar of our faith. It is part of a sacred trust to guide us in doing it to any of our Heavenly Father’s children. This is not easy. It is a choice that is not completely superficial. It is the most important ways to support themselves and to protect them in ways that are destructive.
#  The
# As a disciple of Jesus Christ, I testify of Jesus Christ, who leads us today. We revere the Sabbath day. The Lord has declared, "To be able to stand as witnesses of God at all times and in all things, and in all places … that [we] may be in, even until death," the Lord said to the Prophet Joseph Smith:
#  "Therefore, I am the first and the last; I am he who liveth, I am he who was slain; I am your advocate with the Father."
#
# As a disciple of Jesus Christ, I testify of Him in the name of Jesus Christ, amen.
#
#  Only in this way takes the internet, social media, and even the distance to them and to their sons and daughters.
#  The Tabernacle pulpit in this meeting spoke to President Brigham Young and his fellow Apostles, who translated the Book of Mormon and read the Book of Mormon and also from the Old Testament. They have authority to do so.
#  We should remember the Savior saying, "My Father sent me that
# As a disciple of Jesus Christ, I testify of Jesus Christ, in the name of Jesus Christ, amen.
#
#  We need to do the best we can to help our members prepare for the Second Coming of the Savior into mortality, especially in the name of Jesus Christ, amen.
#
#  To be helpful when we serve in the Church, we affirm that whatever the circumstances in life are appropriate, we limit our exercise of moral agency. As Alma said to his ten lepers, "Let no man despise my servant Oliver Christ
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 13/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 43 for epoch 12
# 2822/2822 ━━━━━━━━━━━━━━━━━━━━ 214s 75ms/step - loss: 1.4916
# finished training...
# As a disciple of Jesus Christ, I testify of the truth of these things, in the name of Jesus Christ, amen.
#
#  I have been impressed with the Savior’s promise that "he that believeth and is baptized shall be saved; but he that believeth not shall be damned."
#  The Savior taught, "I am the way, the truth, and the life: no man cometh unto the Father, but by me.
#  "And I will be thy son, and I will redeem all mankind, that one soul shall not be lost; but all
# As a disciple of Jesus Christ, I testify of Him. I testify of the sacred nature of this sacred truth of His gospel. I testify of Him in the name of Jesus Christ, amen.
#
#  I have a testimony that the Savior lives. I testify of Him in the name of Jesus Christ, amen.
#
#  This is the Lord’s work and His kingdom on earth. He is our Savior and Redeemer. I know that He lives. In the name of Jesus Christ, amen.
#
#  Our
# As a disciple of Jesus Christ, I testify that Jesus Christ is the Son of God. I know that He lives. I know He lives. I know that He lives. I know He lives. I know He lives. I know that He lives, and I know that He lives and that He loves us and that He has a body of flesh and bones. We are children of a Heavenly Father, who loves all of His children everywhere.
#  The First Presidency and Quorum of the Twelve are
# As a disciple of Jesus Christ, I testify of Him in the name of Jesus Christ, amen.
#
#  Wherever the Lord prepares a temple, the Lord opens the door for all of Heavenly Father’s children to have the constant companionship of our Heavenly Father to change our hearts.
#  This is the promise that we will always have His Spirit to be with us (see D&C 130:3).
#  The Book of Mormon is one of those scriptures: "For whosoever will save his life shall lose it: and whosoever will lose
# As a disciple of Jesus Christ, I testify of Jesus Christ, whose Atonement, and His Resurrection is to those who obey His laws.
#  We are to teach our children to be provident Latter-day Saints. We want to be worthy of the presidency of the ward.
#  President Smith taught us in this dispensation: "The Father has a body of flesh and bones; … for through him he is risen and that all men are redeemed, immersed and changed through disobedience (see D&C 46:6; 42:16; Hel. 14:23–24;
# As a disciple of Jesus Christ, I testify of the power of our Savior’s Atonement and Resurrection. He is able to provide fresh priesthood power in the way that He has entrusted the judgment of His laws. Our personal conversion to Jesus Christ and His gospel is one of the most sacred ordinances of our religion. We must exercise our faith and serve the Savior, we are ultimately refined by the giving of their lives. But there is a divine measure of wisdom and understanding that a loving, living, and liberal testimony will continue to flow with a
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 14/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 45 for epoch 13
# 2699/2699 ━━━━━━━━━━━━━━━━━━━━ 206s 76ms/step - loss: 1.4538
# finished training...
# As a disciple of Jesus Christ, I testify of Him and of His Son, Jesus Christ, and in the Holy Ghost, and in the Holy Ghost."
#  The Prophet Joseph Smith said that the Lord "worketh by power, according to the faith of the children of men," the Lord said, "And inasmuch as they sought to destroy the agency of man, which I, the Lord, am well pleased, speaking unto the church collectively and not individually, to minister to the church, to bless the church by the laying on of
# As a disciple of Jesus Christ, I testify of Him and His Son, Jesus Christ, and in the Holy Ghost" (Articles of Faith 1:1).
#  The Prophet Joseph Smith taught, "There is no greater way to care for others than to date the Church."
#  I have learned that I will not have to worry about finances or resist those things which are bad and what we do.
#  There is a difference between the Holy Ghost and the gift of the Holy Ghost.
#  The Savior also taught
# As a disciple of Jesus Christ, I testify that Jesus Christ lives; He is our Father. I know that Jesus is the Christ, the Son of God, the Only Begotten of the Father. Their Heavenly Father and Jesus Christ is the Son of God, our Redeemer, and our Redeemer. He is our Savior, our Redeemer, our Redeemer. Through the Atonement He has provided for us. I testify of Him and invoke His blessings upon the leaders of the Church and their leaders. This includes the
# As a disciple of Jesus Christ, I testify that the Book of Mormon is the word of God and that the Church is concerned only with young women and little girls with a full team of people serving in the Church. Elder D. Todd Christofferson and President M. Russell Ballard sustain Russell Marion Nelson as prophet, seer, and revelator and President of The Church of Jesus Christ of Latter-day Saints. I know that President Russell M. Nelson is God’s prophet today. I testify that Jesus Christ lives
# As a disciple of Jesus Christ, I testify in a sacred name in the name of Jesus Christ, amen.
#
#  You can learn what these young people do to draw upon your husbands and sons and youth in the Church, the other quorum presidency will not translate the word atonement from the title page to teach yourself about the principle of sacrifice that qualify us for the promise that we will "always have his Spirit to be with [us]" (D&C 20:77).
#  The Savior was doomed to death and a final judgment,
#  His
# As a disciple of Jesus Christ, I testify that he has communicated to you that He is a member of the Godhead who leads His Church today in our modern kingdom. The Savior said, "I am the light of the world: he that followeth me shall not walk in darkness, but shall have the light of life" (John 8:12). This includes the final and ultimate triumph of our individual lives. This includes the payment of tithing and make decisions between husband and wife which is particularly precious in their own lives.
#  But these include the
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 15/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 47 for epoch 14
# 2586/2586 ━━━━━━━━━━━━━━━━━━━━ 199s 76ms/step - loss: 1.4103
# finished training...
# As a disciple of Jesus Christ, I testify of Him in the name of Jesus Christ, amen.
#
#  I have felt the Spirit of the Lord with all thine heart; and lean not unto thine own body.
#  "And he that receiveth my Father receiveth my Father’s kingdom; but they that are according to the flesh how to succor his people according to their infirmities."
#  In the name of Jesus Christ, amen.
#
#  I will now present the General Authorities, Area Seventies, and General Officers as presently constituted.
# As a disciple of Jesus Christ, I testify that Jesus is the Christ, our Savior and our Redeemer. The Savior is the Savior of the world. We are His disciples, and He is our Savior and Redeemer. This is His Church. I testify of Him and invoke His blessings upon you, our youth, and I humbly pray in the name of Jesus Christ. Amen.
#
#  I bear witness that President Russell M. Nelson is God’s prophet today. I testify that President Russell M.
# As a disciple of Jesus Christ, I testify of the Father and the Son (see D&C 20:77, 79).
#  I promise that if we are to be peaceable followers of Christ, we are promised that we will always have His Spirit to be with us. I testify that He lives. In the name of Jesus Christ, amen.
#
#  I have known some who are abusive. They are not very ill, and we are not careful. We are upset when we are trying to keep our children focused on the Savior
# As a disciple of Jesus Christ, I testify of our Savior, whose atoning sacrifice gives us the opportunity to be cleansed of our sins when we repent, repent of our sins, and cleanse us from sin. We should be gentle about how we live, how we spend our time. In this manner we have an increased understanding of the Savior’s Atonement and our works on the conditions of mortality. The Savior’s Atonement and His atoning sacrifice are all-consuming. It is the conviction that sustains us in our adversities. The Lord said, "We believe in
# As a disciple of Jesus Christ, I testify that He lives. He is our Father. This is His church, and I know that Jesus Christ lives. I bear my witness and witness that I know He lives. I know He lives. I know He lives. I know He lives. I know the Savior lives. I know He lives. I know He lives. I know He will inspire the faithful children of God out of His arms, minds, minds, minds, hearts, minds, minds, minds; pray in
# As a disciple of Jesus Christ, I testify that now it is true. I have the guidance of the Spirit to be with you as you worthily partake of the sacrament. Do not compromise your qualifications to follow the counsel of your bishop. It may be possible because you can be honored by your priesthood leader. You are our brother’s keeper. And why do I cease to gather him in vain?) will make a difference so as to why the Church is not in the Church. It is not the right thing to do with animals or shelter.
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 16/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 49 for epoch 15
# 2483/2483 ━━━━━━━━━━━━━━━━━━━━ 193s 77ms/step - loss: 1.3762
# finished training...
# As a disciple of Jesus Christ, I testify of Jesus Christ, our Savior and Redeemer, the Lord Jesus Christ. I testify that He lives. He is our Savior, our Redeemer. He is our Savior, our Redeemer. I know He lives and that He is our Savior and Redeemer, our Redeemer, our Mediator, our Redeemer. In the name of Jesus Christ, amen.
#
#  The Lord has declared, "The Holy Ghost shall be [their] constant companion, and [their] scepter an unchanging scepter
# As a disciple of Jesus Christ, I testify of the power of the Holy Ghost that Jesus is the Christ, the Son of the living God. He is the Creator of the world, the Redeemer of the world. He is our Savior, our Redeemer. He is the Creator and Governor of the universe. We are to "pray always" (Mosiah 4:19). The Lord has declared that "the voice of the Lord came into my mind." He told Corianton that "Simon, son of God, have mercy on us
# As a disciple of Jesus Christ, I testify of Christ, our Lord and Savior, Jesus Christ. We are followers of Jesus Christ. He is our Savior, our Redeemer. He is our Savior, our Redeemer. This Church is His Church. He is the Son of God. I know that He lives. I know He lives. I know He lives. I know He lives. In the name of Jesus Christ, amen.
#
#  I have been touched by the tender mercies of the Holy
# As a disciple of Jesus Christ, I testify to you that I know that Jesus is the Christ, the Son of God, the Only Begotten of the Father in the flesh. And if you are careful in the words of some of those scriptures, you do not have to decide to live a life more meaningful, never more terrible than you may have say or how you can safely control your thoughts and your passions and the lift of the soul. It is in the power of His Church. He is the Creator and angels among men
# ...
# finished training...
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and that he is the father of our spirits. Jesus is the Christ, the Son of God. He stands at the head of this Church. Joseph Smith was the prophet of God through whom the gospel of Jesus Christ was restored in these, the latter days. President Ezra Taft Benson is the Lord’s prophet today. He directs this Church by revelation. I bear this testimony humbly in the name of our Lord and Savior, Jesus Christ
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and that he is the father of our spirits. Jesus is the Christ, the Son of God. He stands at the head of this Church. Joseph Smith was the prophet of God through whom the gospel of Jesus Christ was restored in these, the latter days. President Ezra Taft Benson is the Lord’s prophet today. He directs this Church by revelation. I bear this testimony humbly in the name of our Lord and Savior, Jesus Christ
# As a disciple of Jesus Christ, I testify with my grief and my burden is light." (Matt. 5:48.)
#  This vision, this silent tribute of three Mormon women, said, "I never served more than one of your brethren in the Seventy. I come each Sunday, as the Presiding Bishop of the Church presides over the preparatory priesthood as a ward member."
#  Elder We had the opportunity to assist him in those circumstances. The success of Relief Society is opened to you, our sisters, in your homes, in your families,
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and that he is the father of our spirits. Jesus is the Christ, the Son of God. He stands at the head of this Church. Joseph Smith was the prophet of God through whom the gospel of Jesus Christ was restored in these, the latter days. President Ezra Taft Benson is the Lord’s prophet today. He directs this Church by revelation. I bear this testimony humbly in the name of our Lord and Savior, Jesus Christ
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and that he is the father of our spirits. Jesus is the Christ, the Son of God. He stands at the head of this Church. Joseph Smith was the prophet of God through whom the gospel of Jesus Christ was restored in these, the latter days. President Ezra Taft Benson is the Lord’s prophet today. He directs this Church by revelation. I bear this testimony humbly in the name of our Lord and Savior, Jesus Christ
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and that he is the father of our spirits. Jesus is the Christ, the Son of God. He stands at the head of this Church. Joseph Smith was the prophet of God through whom the gospel of Jesus Christ was restored in these, the latter days. President Ezra Taft Benson is the Lord’s prophet today. He directs this Church by revelation. I bear this testimony humbly in the name of our Lord and Savior, Jesus Christ
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 197/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 256 for epoch 196
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 102s 206ms/step - loss: 0.0338
# finished training...
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the Lord’s prophet who directs this work today. I bear this testimony in the name of Jesus Christ, amen.
#
#  In April of 1998, President Hinckley announced the construction of many more small temples, thereby bringing the sacred ordinances of the
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the Lord’s prophet who directs this work today. I bear this testimony in the name of Jesus Christ, amen.
#
#  In April of 1847, Brigham Young led the first company of pioneers out of Winter Quarters. At that same
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the Lord’s prophet who directs this work today. I bear this testimony in the name of Jesus Christ, amen.
#
#  In April of 1847, Brigham Young led the first company of pioneers out of Winter Quarters. At that same
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the Lord’s prophet who directs this work today. I bear this testimony in the name of Jesus Christ, amen.
#
#  In April of 1847, Brigham Young led the first company of pioneers out of Winter Quarters. At that same
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ.
#  How are we to respond to our changing world? While some are neglecting their faith, others are searching for the truth. We have taken upon ourselves the name of the Savior. What more are we to do?
#  Part of our answer may come as we remember how the Lord tutored President Russell M. Nelson in the months prior to his call as President of the Church. Speaking
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and that he is the father of our spirits. Jesus is the Christ, the Son of God. He stands at the head of this Church. Joseph Smith was the prophet of God through whom the gospel of Jesus Christ was restored in these, the latter days. President Ezra Taft Benson is the Lord’s prophet today. He directs this Church by revelation. I bear this testimony humbly in the name of our Lord and Savior, Jesus Christ
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 198/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 256 for epoch 197
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 101s 205ms/step - loss: 0.0342
# finished training...
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. This is his church. Joseph Smith is a true prophet of God, as is President Ezra Taft Benson. I bear this testimony humbly, in the name of Jesus Christ, amen.
#
#  One of the greatest blessings we can offer to the world is the power of a Christ-centered home where the gospel is taught, covenants are kept, and love check.
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the Lord’s prophet who directs this work today. I bear this testimony in the name of Jesus Christ, amen.
#
#  It is no small undertaking to stand before you this evening. I am impressed by your faith, in awe of your potential
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the Lord’s prophet who directs this work today. I bear this testimony in the name of Jesus Christ, amen.
#
#  The Atonement of Jesus Christ and His plan of happiness has been opened through the clouds of Jesus of Nazareth.
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the Lord’s prophet who directs this work today. I bear this testimony in the name of Jesus Christ, amen.
#
#  The Prophet Joseph Smith was often asked to inquire of the Lord to learn what people should do. In the
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the Lord’s prophet who directs this work today. I bear this testimony in the name of Jesus Christ, amen.
#
#  It is no small undertaking to stand before you this evening. I am impressed by your faith, in awe of your potential
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each one of us. I know that Jesus is the Christ and that He loves us. There is no way He wants us to be and then prepare us for it. He has promised:
#  "I will not leave you comfortless: I will come to you" (John 14:17). However, he then compares wonderful behavior in his or her life. Our spiritual endeavor accompany us to be what we should be.
#  There are some who believe
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 199/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 256 for epoch 198
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 102s 206ms/step - loss: 0.0345
# finished training...
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the Lord’s prophet who directs this work today. I bear this testimony in the name of Jesus Christ, amen.
#
#  The Atonement of Jesus Christ and His plan of happiness has been opened through the misuse of those ordinances. Yet
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ.
#  How are we to respond to our changing world? While some are neglecting their faith, others are searching for the truth. We have taken upon ourselves the name of the Savior. What more are we to do?
#  Part of our answer may come as we remember how the Lord tutored President Russell M. Nelson in the months prior to his call as President of the Church. Speaking
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the Lord’s prophet who directs this work today. I bear this testimony in the name of Jesus Christ, amen.
#
#  The Atonement of Jesus Christ and His plan of happiness has been opened through the instrumentality of his chosen prophets.
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ.
#  How are we to respond to our changing world? While some are neglecting their faith, others are searching for the truth. We have taken upon ourselves the name of the Savior. What more are we to do?
#  Part of our answer may come as we remember how the Lord tutored President Russell M. Nelson in the months prior to his call as President of the Church. Speaking
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ.
#  How are we to respond to our changing world? While some are neglecting their faith, others are searching for the truth. We have taken upon ourselves the name of the Savior. What more are we to do?
#  Part of our answer may come as we remember how the Lord tutored President Russell M. Nelson in the months prior to his call as President of the Church. Speaking
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ.
#  How are we to respond to our changing world? While some are neglecting their faith, others are searching for the truth. We have taken upon ourselves the name of the Savior. What more are we to do?
#  Part of our answer may come as we remember how the Lord tutored President Russell M. Nelson in the months prior to his call as President of the Church. Speaking
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 200/200
# File 'all_talks.txt' found locally. Using it.
# Using sequence length: 256 for epoch 199
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 102s 206ms/step - loss: 0.0353
# finished training...
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and that he is the father of our spirits. Jesus is the Christ, the Son of God. He stands at the head of this Church. Joseph Smith was the prophet of God through whom the gospel of Jesus Christ was restored in these, the latter days. President Ezra Taft Benson is the Lord’s prophet today. He directs this Church by revelation. I bear this testimony humbly in the name of our Lord and Savior, Jesus Christ
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the Lord’s prophet who directs this work today. I bear this testimony in the name of Jesus Christ, amen.
#
#  In April of 1847, Brigham Young led the first company of pioneers out of Winter Quarters. At that same
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and that he is the father of our spirits. Jesus is the Christ, the Son of God. He stands at the head of this Church. Joseph Smith was the prophet of God through whom the gospel of Jesus Christ was restored in these, the latter days. President Ezra Taft Benson is the Lord’s prophet today. He directs this Church by revelation. I bear this testimony humbly in the name of our Lord and Savior, Jesus Christ
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and that he is the father of our spirits. Jesus is the Christ, the Son of God. He stands at the head of this Church. Joseph Smith was the prophet of God through whom the gospel of Jesus Christ was restored in these, the latter days. President Ezra Taft Benson is the Lord’s prophet today. He directs this Church by revelation. I bear this testimony humbly in the name of our Lord and Savior, Jesus Christ
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and that he is the father of our spirits. Jesus is the Christ, the Son of God. He stands at the head of this Church. Joseph Smith was the prophet of God through whom the gospel of Jesus Christ was restored in these, the latter days. President Ezra Taft Benson is the Lord’s prophet today. He directs this Church by revelation. I bear this testimony humbly in the name of our Lord and Savior, Jesus Christ
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the Lord’s prophet who directs this work today. I bear this testimony in the name of Jesus Christ, amen.
#
#  Following Jesus Christ, you will overcome and conquer.
#  President David O. Mckay was the prophet during my teenage
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# Final epoch (200) reached.
# Model saved as models/conf-t4-200e_curric.keras

# %%
speakers = ['david-a-bednar', 'dieter-f-uchtdorf', 'jeffrey-r-holland', 'russell-m-nelson', 'thomas-s-monson', 'patrick-kearon']

# %%
for speaker in speakers:
  name = f'speakers/{speaker}'
  run(name)

# %%
model.load_weights("models/conf-t4-200e.keras")
for temp in [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]:
    produce_sample(model, vectorize_layer, vocabulary, temp, num_epochs_total - 1, 'What does the fox say?')

# %%
final_seed_text = "The world seemed like such a peaceful place until the magic tree was discovered in London."
model_path = 'models/'
response_path = 'saved_files/responses/'

base_filename = f'conf-t{main_test_num}-{base_epochs}e_{learn_type}'
file_end = f'-t{transfer_test_num}-{transfer_epochs}e'

keras_ext = '.keras'
response_ext = '.txt'

# %%
def save_responses(model_file, response_file, seed_text):
    model.load_weights(model_file)
    for temp in [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]:
        response = \
            produce_sample(model,
                vectorize_layer,
                vocabulary,
                temp,
                num_epochs_total - 1,
                seed_text,
                length=1000,
                do_print=False)
        with open(response_file, 'a') as f:
            f.write(f"Temp: {temp}\n")
            f.write(response)
            f.write('\n\n')
    print(f"Response saved as {response_path + response_file}")

# %%
for speaker in speakers:
    last_name = '_' + speaker.split('-')[-1]
    keras_filename = model_path + base_filename + last_name + file_end + keras_ext
    response_filename = response_path + base_filename + last_name + file_end + response_ext
    save_responses(keras_filename, response_filename, final_seed_text)

# %%
general_keras_filename = model_path + base_filename + keras_ext
general_response_filename = response_path + base_filename + response_ext
save_responses(general_keras_filename, general_response_filename, final_seed_text)
# Out:
# Response saved as saved_files/responses/saved_files/responses/conf-t4-200e_curric.txt
