# %% [markdown]
# ### Setup

# %%
# Import libraries

# import contextlib
import gc
# import io
# import numpy as np
import os
# import random
import re
import string
import time

os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"

import tensorflow as tf
from tensorflow.keras import Sequential # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D, StringLookup, TextVectorization # type: ignore

# NOTE: testing
# print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2025-03-28 22:36:16.559512: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-28 22:36:16.767679: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743222976.838833     873 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743222976.858236     873 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-28 22:36:17.051902: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
RESTART = False
TRANSFER = True
if TRANSFER:
    BATCH_SIZE = 64
    LEARNING_RATE = 0.00005
else:
    BATCH_SIZE = 128
    LEARNING_RATE = 0.0005
# BATCH_SIZE = 64
EPOCH_TO_PICKUP = 100
PATH = ''
VOCAB_SIZE = 8192
SEQUENCE_LENGTH = 128
BUFFER_SIZE = 10000
TEACHER_FORCED = False

# %% [markdown]
# ### Text Processing

# %%
def preprocess_text(text):

    # fix quotes
    text = text.replace("“", "\"")
    text = text.replace("”", "\"")

    # Replace any capital letter at the start of a word with ^ followed by the lowercase letter
    text = re.sub(r"(?<![a-zA-Z])([A-Z])", lambda match: f"^{match.group(0).lower()}", text)

    # Replace all other capital letters with lowercase
    text = re.sub(r"([A-Z])", lambda match: f"{match.group(0).lower()}", text)

    # Replace whitespace characters with special words
    text = re.sub(r"(\t)", r" zztabzz ", text)
    text = re.sub(r"(\n)", r" zznewlinezz ", text)
    text = re.sub(r"(\s)", r" zzspacezz ", text)

    # Split before and after punctuation
    for punctuation in string.punctuation:
        text = text.replace(punctuation, f" {punctuation} ")

    return text

def postprocess_text(text):

    # Replace special words with whitespace characters
    text = text.replace("zztabzz", "\t")
    text = text.replace("zznewlinezz", "\n")
    text = text.replace("zzspacezz", " ")

    # Remake capital letters at beginning of words
    text = re.sub(r"\^([a-z])", lambda match: f"{match.group(1).upper()}", text)

    text = text.replace("^", "")

    return text

def getMyText(filename='all_talks_2000.txt'):
    file_name = filename
    local_dir = 'saved_files'
    local_path = os.path.join(local_dir, file_name)

    try:
        # Ensure the directory exists
        if not os.path.exists(local_dir):
            os.makedirs(local_dir)

        # Check if the file exists locally
        if os.path.exists(local_path):
            print(f"File '{file_name}' found locally. Using it.")
        else:
            print(f"File '{file_name}' not found.")
            return

        # Read the file's contents
        with open(local_path, 'rb') as file:
            text = file.read().decode(encoding='utf-8')

        return preprocess_text(text)

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
if RESTART:
  vocab_text = getMyText()

  ### Make vocabulary (Adapted from TensorFlow word embedding tutorial)
  # Use the text vectorization layer to normalize, split, and map strings to
  # integers. Note that the layer uses the custom standardization defined above.
  # Set maximum_sequence length as all samples are not of the same length.
  vectorize_layer = TextVectorization(
      standardize='lower',
      split='whitespace',
      max_tokens=VOCAB_SIZE,
      output_mode='int',
      )
  # Make a text-only dataset (no labels) and call adapt to build the vocabulary.
  vectorize_layer.adapt([vocab_text])
  vocabulary = vectorize_layer.get_vocabulary()

  ### Save Vocabulary
  with open(PATH + "vocabulary.txt", "w") as file:
    for word in vocabulary:
        file.write(word + "\n")
else:
  ### Load Saved Vocabulary
  with open(PATH + "vocabulary.txt", "r") as file:
      vocabulary = [word.strip() for word in file.readlines()]
      vocabulary = vocabulary

  vectorize_layer = TextVectorization(
      vocabulary=vocabulary,
      standardize='lower',
      split='whitespace',
      max_tokens=VOCAB_SIZE,
      output_mode='int',
      )
  
# NOTE: testing
# print(vocabulary[:20])
# print(vocabulary[-20:])
# Out:
# I0000 00:00:1743222987.324186     873 gpu_process_state.cc:201] Using CUDA malloc Async allocator for GPU: 0
# I0000 00:00:1743222987.325069     873 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13499 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# This function will generate our sequence pairs:
def split_input_target(sequence):
    input_ids = sequence[:-1]
    target_ids = sequence[1:]
    return input_ids, target_ids

# This function will create the dataset
def text_to_dataset_teacher_forced(text, *args, **kwargs):
  
    all_ids = vectorize_layer(text)
    ids_dataset = tf.data.Dataset.from_tensor_slices(all_ids)
    del all_ids
    sequences = ids_dataset.batch(SEQUENCE_LENGTH+1, drop_remainder=True)
    del ids_dataset

    # Call the function for every sequence in our list to create a new dataset
    # of input->target pairs
    dataset = sequences.map(split_input_target)
    del sequences

    return dataset

def text_to_dataset_curriculum_learning(text, initial_seq_length=24, max_seq_length=SEQUENCE_LENGTH*1.5, growth_factor=1.025, current_epoch=0):
    """
    Implements curriculum learning by gradually increasing sequence length as training progresses.
    
    Parameters:
        text (str): The input text data.
        initial_seq_length (int): The starting sequence length.
        max_seq_length (int): The maximum sequence length.
        growth_factor (float): The rate at which sequence length increases per epoch.
        current_epoch (int): The current training epoch.
    
    Returns:
        tf.data.Dataset: The processed dataset with gradually increasing sequence length.
    """
    # Compute the sequence length dynamically based on the current epoch
    sequence_length = min(int(max_seq_length), int(initial_seq_length * (growth_factor ** current_epoch)))
    
    print(f"Using sequence length: {sequence_length} for epoch {current_epoch + 1}")
    
    # Convert text to token IDs
    all_ids = vectorize_layer(text)
    ids_dataset = tf.data.Dataset.from_tensor_slices(all_ids)
    del all_ids

    # Create sequences with the dynamically determined length
    sequences = ids_dataset.batch(sequence_length, drop_remainder=True)
    del ids_dataset

    # Create input-target pairs (teacher forcing still applies, but curriculum learning controls sequence length)
    dataset = sequences.map(split_input_target)
    del sequences

    return dataset


def text_from_ids(ids):
    text = ''.join([vocabulary[index] for index in ids])
    return postprocess_text(text)

def setup_dataset(dataset):
    dataset = (
      dataset
      .shuffle(BUFFER_SIZE)
      .batch(BATCH_SIZE, drop_remainder=True)
      .prefetch(tf.data.experimental.AUTOTUNE))
    return dataset

# %%
if TEACHER_FORCED:
    learning_mode_fn = text_to_dataset_teacher_forced
else:
    learning_mode_fn = text_to_dataset_curriculum_learning

vocabulary_adjusted = vocabulary
vocabulary_adjusted[0] = '[UNK]'
vocabulary_adjusted[1] = ''
words_from_ids = tf.keras.layers.StringLookup(vocabulary=vocabulary_adjusted, invert=True)

if RESTART:
  vocab_ds = learning_mode_fn(vocab_text)
  for input_example, target_example in vocab_ds.take(1):
    print("Input: ")
    print(input_example)
    print(text_from_ids(input_example))
    print(words_from_ids(input_example))
    print("Target: ")
    print(target_example)
    print(text_from_ids(target_example))
    
  vocab_ds = setup_dataset(vocab_ds)

  dataset = vocab_ds
  del vocab_text
  del vocab_ds
else:
  dataset = learning_mode_fn(getMyText())
  dataset = setup_dataset(dataset)
# Out:
# File 'all_talks_2000.txt' found locally. Using it.
# Using sequence length: 24 for epoch 1

# %% [markdown]
# ### Model Building

# %%
# Create our custom model. Given a sequence of characters, this
# model's job is to predict what character should come next.
class ConferenceTextModel(tf.keras.Model):

  # This is our class constructor method, it will be executed when
  # we first create an instance of the class
  def __init__(self, vocab_size, embedding_dim, rnn_units):
    super().__init__()

    # Our model will have three layers:

    # 1. An embedding layer that handles the encoding of our vocabulary into
    #    a vector of values suitable for a neural network
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)

    # 2. A GRU layer that handles the "memory" aspects of our RNN. If you're
    #    wondering why we use GRU instead of LSTM, and whether LSTM is better,
    #    take a look at this article: https://datascience.stackexchange.com/questions/14581/when-to-use-gru-over-lstm
    #    then consider trying out LSTM instead (or in addition to!)
    self.lstm1 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
    self.lstm2 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
    self.lstm3 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)


    self.hidden1 = tf.keras.layers.Dense(embedding_dim*64, activation='relu')
    self.hidden2 = tf.keras.layers.Dense(embedding_dim*16, activation='relu')

    # 3. Our output layer that will give us a set of probabilities for each
    #    character in our vocabulary.
    self.dense = tf.keras.layers.Dense(vocab_size)

    # Define default initial states as None (they will be created once)
    self.initial_states = None

  def get_initial_states(self, batch_size):
    """Generate initial states once per batch"""
    return [
        [tf.zeros([batch_size, self.lstm1.units]), tf.zeros([batch_size, self.lstm1.units])],
        [tf.zeros([batch_size, self.lstm2.units]), tf.zeros([batch_size, self.lstm2.units])],
        [tf.zeros([batch_size, self.lstm3.units]), tf.zeros([batch_size, self.lstm3.units])],
    ]
  
  # This function will be executed for each epoch of our training. Here
  # we will manually feed information from one layer of our network to the
  # next.

  def call(self, inputs, states=None, return_state=False, training=False):
    x = self.embedding(inputs, training=training)
    batch_size = tf.shape(inputs)[0]

    # Use pre-defined function to get initial states
    if states is None:
        states = self.get_initial_states(batch_size)

    # LSTM layers process input sequentially
    x, state_h_1, state_c_1 = self.lstm1(x, initial_state=states[0], training=training)
    states_out_1 = [state_h_1, state_c_1]

    x, state_h_2, state_c_2 = self.lstm2(x, initial_state=states[1], training=training)
    states_out_2 = [state_h_2, state_c_2]

    x, state_h_3, state_c_3 = self.lstm3(x, initial_state=states[2], training=training)
    states_out_3 = [state_h_3, state_c_3]

    states_out = [states_out_1, states_out_2, states_out_3]

    x = self.hidden1(x, training=training)
    x = self.hidden2(x, training=training)
    x = self.dense(x, training=training)

    return (x, states_out) if return_state else x
  
'''
----------------------------------------------------------------------------------------------------
'''
# Here's the code we'll use to sample for us. It has some extra steps to apply
# the temperature to the distribution, and to make sure we don't get empty
# characters in our text. Most importantly, it will keep track of our model
# state for us.

class OneStep(tf.keras.Model):
  def __init__(self, model, vectorize_layer, vocabulary, temperature=1):
    super().__init__()
    self.temperature=temperature
    self.model = model
    self.vectorize_layer = vectorize_layer
    self.vocabulary = vocabulary

    # Create a mask to prevent "" or "[UNK]" from being generated.
    skip_ids = StringLookup(vocabulary=list(vocabulary))(['', '[UNK]'])[:, None]
    sparse_mask = tf.SparseTensor(
        # Put a -inf at each bad index.
        values=[-float('inf')]*len(skip_ids),
        indices = skip_ids,
        # Match the shape to the vocabulary
        dense_shape=[len(vocabulary)])
    self.prediction_mask = tf.sparse.to_dense(sparse_mask,validate_indices=False)

  @tf.function
  def generate_one_step(self, inputs, states=None):
    # Convert strings to token IDs.
    input_ids = self.vectorize_layer(inputs)

    # Run the model.
    # predicted_logits.shape is [batch, char, next_char_logits]
    predicted_logits, states =  self.model(inputs=input_ids, states=states,
                                          return_state=True)
    del input_ids
    # Only use the last prediction.
    predicted_logits = predicted_logits[:, -1, :]
    predicted_logits = predicted_logits/self.temperature

    # Apply the prediction mask: prevent "" or "[UNK]" from being generated.
    predicted_logits = predicted_logits + self.prediction_mask

    # Sample the output logits to generate token IDs.
    predicted_ids = tf.random.categorical(predicted_logits, num_samples=1)
    del predicted_logits
    predicted_ids = tf.squeeze(predicted_ids, axis=-1)

    # Return the characters and model state.
    return words_from_ids(predicted_ids), states

'''
----------------------------------------------------------------------------------------------------
'''

def produce_sample(model, vectorize_layer, vocabulary, temp, epoch, prompt, length=200, do_print=True):
  one_step_model = OneStep(model, vectorize_layer, vocabulary, temp)
  states = None
  next_char = tf.constant([preprocess_text(prompt)])
  result = [tf.constant([prompt])]

  for _ in range(length):
    next_char, states = one_step_model.generate_one_step(next_char, states=states)
    result.append(next_char)

  result = tf.strings.join(result)
  if do_print:
    print(postprocess_text(result[0].numpy().decode('utf-8')))
    print('Epoch: ' + str(epoch) + '\n', file=open(PATH + 'tree.txt', 'a'))
    print('Temp: ' + str(temp) + '\n', file=open(PATH + 'tree.txt', 'a'))
    print(postprocess_text(result[0].numpy().decode('utf-8')), file=open(PATH + 'tree.txt', 'a'))
    print('\n\n', file=open(PATH + 'tree.txt', 'a'))
    del states
    del next_char
    del result
  else:
    return postprocess_text(result[0].numpy().decode('utf-8'))

# %%
embedding_dim = 128
rnn_units = 512
model = ConferenceTextModel(VOCAB_SIZE, embedding_dim, rnn_units)

# NOTE: testing OR transfer learning
# Verify the output of our model is correct by running one sample through
# This will also compile the model for us. This step will take a bit.
for input_example_batch, target_example_batch in dataset.take(1):
    example_batch_predictions = model(input_example_batch)
    print(example_batch_predictions.shape, "# (BATCH_SIZE, sequence_length, VOCAB_SIZE)")

# NOTE: more testing
# model.summary()
# Out:
# (128, 23, 8192) # (BATCH_SIZE, sequence_length, VOCAB_SIZE)
# I0000 00:00:1743223161.571219    1180 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-03-28 22:39:21.727053: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ### Model Training

# %%
if TRANSFER:
  model_file_to_load = "conf-t5-100e_curric.keras"
  model.load_weights(PATH + 'models/' + model_file_to_load)

# %%
early_stop = EarlyStopping(
    monitor='loss',
    min_delta=0.01,
    patience=5,
    restore_best_weights=True
)
loss = tf.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=opt, loss=loss)

base_epochs = 200
transfer_epochs = 50
num_epochs_total = base_epochs + transfer_epochs
main_test_num = 4
transfer_test_num = 1

if TEACHER_FORCED:
    learn_type = 'teacher'
else:
    learn_type = 'curric'

if RESTART:
  start_epoch = 0
else:
  start_epoch = EPOCH_TO_PICKUP

# %%
def run(name='all_talks_2000'):
  stop_training = False
  for e in range(start_epoch, num_epochs_total):
    if stop_training:
      print(f"Early stopping triggered at epoch {e + 1}. Exiting training.")
      break
    success = False
    while(success == False):
      try:
        print(f'{time.strftime("%H:%M:%S", time.localtime(time.time()))} - epoch: {e + 1}/{num_epochs_total}')
        new_text = getMyText(f'{name}.txt')
        # dataset = learning_mode_fn(new_text, current_epoch=e)
        dataset = learning_mode_fn(new_text, growth_factor=1.05, current_epoch=e)
        # print("Dataset created...")
        del new_text
        dataset = setup_dataset(dataset)
        # print("Dataset set up...")
        model.optimizer.learning_rate.assign(LEARNING_RATE*(0.99**e))
        # print("Model is fitting...")
        model.fit(dataset, epochs=1, verbose=1, callbacks=[early_stop])
        if early_stop.stopped_epoch > 0:
          stop_training = True
        print(f"finished training epoch: {e + 1}...\n")
        del dataset
        for temp in [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]:
          produce_sample(model, vectorize_layer, vocabulary, temp, e, 'As a disciple of Jesus Christ, I testify')
        print("\nsamples produced...")
        gc.collect()
        print("garbage collected...")
        tf.keras.backend.clear_session()
        print("session cleared (to save memory)...\n")
        success = True
      except:
        gc.collect()
        tf.keras.backend.clear_session()
        try:
          del dataset
        except:
          print("dataset was not produced or has already been deleted")
        print("retrying epoch: " , e + 1)

  print(f'\nFinal epoch ({num_epochs_total}) reached.')
  filename = f'models/conf-t{main_test_num}-{base_epochs}e_{learn_type}'
  if base_epochs < num_epochs_total:
    filename += f'_{name.split("-")[-1]}-t{transfer_test_num}-{transfer_epochs}e'
  filename += '.keras'
  model.save(filename)
  print(f"Model saved as {filename}")

# %%
# NOTE: testing
# dataset = learning_mode_fn(getMyText(), growth_factor=1.05, current_epoch=43)

# %%
run() # just once, for training from scratch
# Out:
# 12:35:39 - epoch: 43/100
# File 'all_talks_2000.txt' found locally. Using it.
# Using sequence length: 186 for epoch 43
# I0000 00:00:1743100547.506548    1205 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 117s 337ms/step - loss: 4.3126
# finished training epoch: 43...
#
# As a disciple of Jesus Christ, I testify to I Christ, and I and His Jesus I Christ, Savior was His Church to the I the I I I Christ, of I I I I His Lord of I the Twelve to I I Christ, the I I I I God of God to the I day. I Christ to I I the I Church, the I I I the God to I I I I Christ in I Church
# As a disciple of Jesus Christ, I testify in I I the Lord of I His England, I God. I in a the I the the If I I the God I His Church to the I His I the I I I the I I, I Christ. I with Christ and I Church, Son to Lord is I Christ, the His I the I the I I I the Lord’s In I Christ to Lord I Bible that I
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 113s 345ms/step - loss: 2.3243
# finished training epoch: 49...
#
# As a disciple of Jesus Christ, I testify that I am the Christ of Latter-day Saints. The Lord has said to the Light of God. He is the Father and His Son. This is the Christ, and the Holy Ghost, Jesus Christ, and the name of Jesus Christ, amen.
#
#  I testify that the Lord said, "I will be able to do eternal life, and to do with the name of Christ, and I will be with you that I have done in Christ, and
# As a disciple of Jesus Christ, I testify that the Holy Ghost will be forgiven, and He wants us to do Him. He is a Son; He said, "I will be baptized and seek the Father and God."
#  I bear witness that I have commanded to be perfect to His Father and His Son. That we have felt our Father in Heaven. We will have been obedient to the Savior Jesus Christ. We felt the Holy Ghost and that His Atonement of Jesus Christ, amen.
#
# As a disciple of Jesus Christ, I testify that Jesus Christ, Jesus Christ, and He has promised His name. He is a Son and His Son, and Him and His Son and His Son, I am well. He and His Son, Jesus Christ, of His Son, and the Son of God, and the Son of God. He is His Son, Jesus Christ, and the Son of God, Jesus Christ, my Son, Jesus Christ, He of Latter-day Saints.
# As a disciple of Jesus Christ, I testify with Him. We will receive the Christ, He loves you, and with Him and living of His love power and comfort and that the Lord’s Atonement and the Son of God, and His Son is the Son, and I gave his gospel, he said that they knew it to be. His Son, Jesus Christ. God, He and His Son in God in a name of Jesus Christ. Amen.
#
#  President Spencer W. Kimball said: "We
# As a disciple of Jesus Christ, I testify of the name of Jesus Christ. Amen.
#
#  Now the Savior said:
#  "O you are possible, for you were," and taste of Him. … Little said: Deseret 6:4–5). He and I I are the Christ and our Eternal love, and "peaceable name and not like us, and eternal church is the servants of God. …
#  "Ye said, and love the Lord, or charity in the Holy Ghost that we can attain upon thee from me, and
# As a disciple of Jesus Christ, I testify that I have given "the things of James: Moses of Me, who was the ], Every American Israelites Bar, that because the Son of Christ, having warned us to me."
#  Two Testament explained: "If a man cried unto the world, and believed to be, and after the final gospel of the church, to stand with fire, it is shed correctly; and ye may worship this are unto them" (Moro. 3:20) by the nature of the Godhead. He is a small
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
#
# 12:50:16 - epoch: 50/100
# File 'all_talks_2000.txt' found locally. Using it.
# Using sequence length: 192 for epoch 50
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 114s 347ms/step - loss: 2.2584
# finished training epoch: 50...
#
# As a disciple of Jesus Christ, I testify that I am the Christ and His Son. I testify that I am with you that God lives in the name of Jesus Christ, amen.
#
#  I testify that I have been grateful for the Lord’s Church to be tested in the Church to the Church. I pray that we are the Lord’s plan to the Holy Ghost to be and to be interested in the Lord’s work. I testify that we are that we can be able to be a few and to be
# As a disciple of Jesus Christ, I testify of the Christ, the Savior Jesus Christ, amen.
#
#  I testify that the Lord revealed that the Lord to the Lord and His Son, Jesus Christ, "for the Lord Jesus Christ, the Son of God, Jesus Christ, and Jesus Christ, amen.
#
#  I testify that I testify of the Christ is the Christ in the name of Jesus Christ, amen.
#
#  We are the Lord’s plan of God, His Son, Jesus
# As a disciple of Jesus Christ, I testify that I know of the Holy Ghost and Savior with the Christ and the Father.
#  As I testify that Jesus Christ, amen.
#
#  I have seen that your faith, we will be faithful, and He lives and we can do our Savior and Jesus Christ. May we do so testify and you are grateful for you with His Spirit with the Holy Ghost to be with us our Father and Eve and His life for the Savior and His Beloved Son
# As a disciple of Jesus Christ, I testify that it is those who I am with each of us to come to His Church, the Lord Himself the Savior.
#  President Nelson has taught that we have to the Lord’s love to the Church when we sustain all of His promises and guides us to be faithful.
#  In the Council of Jesus Christ, our Only Begotten Price: "There is His Son, Jesus Christ, and His Redemption of His Beloved Son, The Eternal Father. Thank you how
# As a disciple of Jesus Christ, I testify of the Only Begotten Son of Latter-day Saints and His teachings. In the name of Jesus Christ, amen.
#
#  Since I am called to her son who was inspired in the Light. In the time of the Church: "To you,’ I do so, let the Savior had "the Holy Ghost is the Lord; and put our angel upon the Son; which is the Holy Ghost in you … and serve" (Matt. 7:49), and the revelation of
# As a disciple of Jesus Christ, I testify that your loneliness I bear unto you the one Jesus Christ, all of this life, and the Spirit of Christ.
#  The Book of Mormon teaches, they will be a covenant with us to have the Savior’s people to keep the end should be ours to your youth.
#  Why is the ongoing testimony for this temple, the members of the service we are taken upon to you, we build our progress from the reality of our beloved name in our Lord, Jesus Christ, and the Apostle James
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
#
# 12:52:21 - epoch: 51/100
# File 'all_talks_2000.txt' found locally. Using it.
# Using sequence length: 192 for epoch 51
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 114s 347ms/step - loss: 2.2027
# finished training epoch: 51...
#
# As a disciple of Jesus Christ, I testify that I have been true to Him in the name of Jesus Christ, amen.
#
#  The Lord said, "If ye have not the Lord, and have faith in the name of Christ, and in the name of Jesus Christ, amen.
#
#  The Lord has said that the Lord is a great gift for the Holy Ghost, the Lord Jesus Christ, amen.
#
#  We are not to be a great and true power for the Holy Ghost. The
# As a disciple of Jesus Christ, I testify that He, Jesus is the Christ, and keep the commandments and eternal life, and receive the will of the Holy Ghost, and that I have spoken unto you, and I have done you to do so with you."
#  I pray that I pray in our Savior in the name of Jesus Christ, amen.
#
#  The Lord Jesus Christ, amen.
#
#  The Savior has said to His disciples upon all His Father, Jesus Christ, and He is the
# As a disciple of Jesus Christ, I testify that Jesus is the Father, and His Son, Jesus Christ, and that He hath sent us to be faithful, and His children will be saved with His holy sacrifice, and He has given us to help you and in our hearts. As we see our vision to be "a Spirit, …
#  "And we are the kingdom of heaven and peaceable life which are saved in the Lord, which is the greatest of all we shall be saved in the kingdom of God … of the earth
# As a disciple of Jesus Christ, I testify that He lives that He has ever love for us and Him.
#  I testify that the Lord gave us to Him, Jesus Christ, and He loves us, I give you all in the name of Jesus Christ, amen.
#
#  The Savior has said, "I that hath no more of my name, that I have spoken of Christ, even unto my name, and I have learned in my name, and set you all to be a good God, and in the name
# As a disciple of Jesus Christ, I testify in the name of Jesus Christ, amen.
#
#  I hope that this is to help you for the Lord loves us, and I pray in the name of Jesus Christ, amen.
#
#  The Book of Mormon is made His people personally: "If any man should be in this earth, we could not good about the Spirit, and let "-are not the children of God ye shall have given up into the covenants of God" (2 Ne. 15:21).
#  We
# As a disciple of Jesus Christ, I testify that the Lord wants the Father, Jesus Christ, and His prophets, and whom He said, "I know that which ye have been in you through my witness to my God, give my effect, and will be his work, and thy name (Matthew 11:41).
#  Jesus Christ caused my Son and knelt upon you about the waters of the Spirit."
#  Though we both were on by high , the precious thing of the Savior, and there was the greatest promise of Jesus Christ,
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
#
# 12:54:26 - epoch: 52/100
# File 'all_talks_2000.txt' found locally. Using it.
# Using sequence length: 192 for epoch 52
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 113s 345ms/step - loss: 2.1518
# finished training epoch: 52...
#
# As a disciple of Jesus Christ, I testify that He lives in the name of Jesus Christ, amen.
#
#  I testify that the Lord will bless us to be with you the Lord and Savior and His Son, Jesus Christ, and His Son, Jesus Christ, and His Son, Jesus Christ. This is the Lord’s Church. I testify that the Lord has given us the Father and His Son, Jesus Christ, and the Lord. I testify that Jesus Christ is the Christ and His
# As a disciple of Jesus Christ, I testify that this is His Church to be with us to do so to be worthy to do the Lord’s help and in the sacred name of Jesus Christ, amen.
#
#  The Lord taught that "the Lord has commanded us to be saved unto you, to [the Father, and the Son of God, and the Son, he suffered the Father of God. And he was a God to the world of the Father, and the Son of God, and the Son of God
# As a disciple of Jesus Christ, I testify that He is a Only Begotten of the world. I bear witness that our Father lives and that we will be the Holy Ghost, that we are not bless us the Holy Ghost to be blessed and His love, and He will bring us to His commandments. In this context, we can be our Spirit, and the Book of Mormon to the earth, "It is the Spirit of God."
#  I testify that the Holy Ghost will be with us of the Lord
# As a disciple of Jesus Christ, I testify that the Lord Jesus Christ, amen.
#
#  As we speak of young people and the Lord will help us increase for the Lord. It is the truth that will be more important and we are called to the end of the Lord and His Atonement. We have been a wonderful commitment to the Church and the Holy Ghost. He has given us more than those that we are to be our children and Heavenly Father, Jesus Christ, and His Atonement, I pray and
# As a disciple of Jesus Christ, I testify for the depths of Their Father, Jesus Christ and His Atonement, our Lord Jesus Christ, Jesus Christ and the Father, Jesus Christ.
#
#  The Lord warned His will so witness of the great Redeemer and His Son.
#  Here by the Doctrine and Covenants adds following the Quorum of the Twelve Apostles. General conference of the Church were referred to the Mount, Joseph Smith Eyring and Elder Women and the Twelve Apostles. A sacred blessing
# As a disciple of Jesus Christ, I testify that through the Holy Ghost as He has revealed for us, living that the prophet of Jesus Christ. This has been clarified; surely the father have unfolded to be more and clear.
#  We have come to more closely to our prayers. The evidence and auxiliary is in President Nelson is based on safety. His purpose, often we learn the privilege of faith, and they witness Him, Jesus Christ, repenting that "we have heard the person and might live in his sight about the ordinances of the
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
#
# 12:56:30 - epoch: 53/100
# File 'all_talks_2000.txt' found locally. Using it.
# Using sequence length: 192 for epoch 53
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 113s 345ms/step - loss: 2.1093
# finished training epoch: 53...
#
# As a disciple of Jesus Christ, I testify that He lives. He is the Holy Ghost to help us to become more like Him. He is the Christ of Jesus Christ, who can be perfected in Him in the earth. In the name of Jesus Christ, amen.
#
#  We are a great example of our Heavenly Father and His Son and His Son, Jesus Christ, and His Father, Jesus Christ, and His Church. The Lord has declared that He will make our covenants and eternal
# As a disciple of Jesus Christ, I testify that He lives and that He is the Son of God. I bear my sure that I have been "a Spirit" (D&C 58:10). In these verses of the Atonement, we must be cleansed of our sins and love for His children.
#  The Savior said that "the Lord doth not be the first foundation, and the doctrine of God may be saved in the world, and the glory of God, and the Son of God, and of the Holy Ghost,
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
#
#
# Final epoch (100) reached.
# Model saved as models/conf-t5-100e_curric.keras

# %%
speakers = ['david-a-bednar', 'dieter-f-uchtdorf', 'jeffrey-r-holland', 'russell-m-nelson', 'thomas-s-monson', 'patrick-kearon']
for speaker in speakers:
  filename = f'speakers/{speaker}'
  run(filename)
# Out:
# 22:39:44 - epoch: 101/125
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 192 for epoch 101
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - loss: 1.1026
# finished training epoch: 101...
#
# As a disciple of Jesus Christ, I testify that in my particular and sure my brother and sister Relief Society is President Gordon B. Hinckley.
#  In May of this I have traveled the world testifying of the Lord Jesus Christ as our Savior and Redeemer. We have been taught the importance of the Lord’s promise that we will always have His Spirit to be with us. In the name of Jesus Christ, amen.
#
#  The Savior taught us to love our enemies and to love our neighbors.
#  As we
# As a disciple of Jesus Christ, I testify with all the certainty that I have in receiving His name among the Prophet Joseph Smith and the other General Authorities in this dispensation.
#  I testify of the truth of these things, in the name of Jesus Christ, amen.
#
#  The Church of Jesus Christ is the only true church of the Lord Jesus Christ. President Ezra Taft Benson is the Lord’s prophet today. I so testify in the name of Jesus Christ, amen.
#
#  The Book of
# As a disciple of Jesus Christ, I testify that we can know the truth and the blessings of the holy priesthood and they will have the blessing of the Holy Ghost is our companion, for "as oft as Jesus is sent to the righteous covenant for the remission of sins." The Savior loves us with our needs and desires. At the end of our everlasting lives, the Savior becomes "to bring to pass the immortality and eternal life of man" (Moses 1:39), I testify in the name of Jesus Christ, amen.
#
#  Continuous
# As a disciple of Jesus Christ, I testify that "peaceable followers and Covenants is a light and a continuation of the seeds forever and ever before God this Jesus of Nazareth." In the sacred name of Jesus Christ, amen.
#
#  Not long ago I heard a little boy in Primary president George Albert Smith. It is not a mere coincidence that I am not fifty-two years of age. On the first date I decided to make a few simple copies of my participation in the holy priesthood in New Mexico and in
# As a disciple of Jesus Christ, I testify of Him as our foundation of faith, that we may be blessed with family connections and by preparing other things into eternity. In addition to our happiness, we should remember that acquiring ordinances and covenants are requirements whereby we should have the blessings promised by the power of the Holy Ghost by the laying on of hands by those in authority, and as surely every word as a and everlasting Son of God is the mighty change of heart and judgment is in accordance with God’s blessings. This increases us to cast our
# As a disciple of Jesus Christ, I testify that "peaceable followers of Christ" can be administered both today to us as we are cherished to become "new creature … [to] dwell with God."
#  The scriptures are replete with admonitions to share the voice of the Spirit. And we are far from Jesus Christ because of the workings of the Holy Ghost. I believe in His words we also testify of the truth of the restored gospel. The Holy Ghost will help you to learn more about Him and keeping His commandments. Your testimony
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
#
# 22:39:57 - epoch: 102/125
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 192 for epoch 102
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - loss: 1.0578
# finished training epoch: 102...
#
# As a disciple of Jesus Christ, I testify that in the sacred name of Jesus Christ, amen.
#
#  My dear brothers and sisters, I am grateful for the opportunity to speak to you this evening. I pray for the Spirit of the Lord to be with me. I pray that we will always remember Him, and we pray that we will always remember Him, and we pray that we will always remember Him, and we pray for you.
#  I pray that we will always remember Him, and He will know our Heavenly
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 0.9638
# finished training epoch: 105...
#
# As a disciple of Jesus Christ, I testify that He lives. And I witness that if we do so, we will be blessed with "every day that proceedeth forth out, even at the doors of the day to come."
#  The Lord has declared, "I will not leave you comfortless: I will come to you."
#  I testify that the Father and the Son, Jesus Christ, are the chief cornerstone, and the Holy Ghost is our Savior. And I witness that we can be blessed to know the truth that Jesus
# As a disciple of Jesus Christ, I testify that in the Holy Spirit we can and will become a source of spiritual strength for good and true disciples of Christ.
#  The Lord Jesus Christ is the Creator of the earth, and He is the Son of God. He is our Savior, our Redeemer, and of His Atonement and Resurrection. He stands with us beyond the capacity of the terrible temptation of our lives.
#  We know He lives and He knows us and our circumstances, our failures, and our actions. We
# As a disciple of Jesus Christ, I testify with the deepest gratitude of Christ for the ministry of the Only Begotten of the Father, which is "the way, the truth, and the life" (John 14:6).
#  I also testify that the Father and the Son are sending up His Spirit to a more and holier approach. He is the Son of God, and He directs His Church, and His Church is everlasting. And I witness and testify that the Savior, the Lord and Savior of all mankind, through
# As a disciple of Jesus Christ, I testify that we have been given the privilege to have the restored gospel of Jesus Christ by entering into sacred covenants a covenant between the sacrament we are partakers of the divine nature.
#  The Prophet Joseph Smith explained: "You should teach the Holy Ghost to be with [us]"20 into these latter days. This requires a great but sacred pattern for all of us. As we remember and honor the holy priesthood and receive the blessings Heavenly Father has provided for us, I have realized that I would
# As a disciple of Jesus Christ, I testify that our Heavenly Father is the source of that hope and promise that we can live in the presence of God. We know that God loves us and is mindful of us, individually, and strength.
#  We can become purified and filled with the Holy Spirit of Promise to Heavenly Father. Many of us are imperfect things to do, but the Lord is real, and the elements of eternal life have been blessed by spiritual hardship. If we will be lost from the Holy Ghost, inappropriate or
# As a disciple of Jesus Christ, I testify that in the sacred name of Jesus Christ, amen.
#
#  Let me tell you of a world song and into the dark shadows of the adversary.
#  My dear brothers and sisters, what a wonderful day of spiritual experience! We all have been blessed for answers about His great and inspiring latter that have been as His work in our day. I bear my testimony that the Savior’s true peace and help repentance will be poured out upon us as He desires for our needs and for everything we do
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
#
# 22:40:41 - epoch: 106/125
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 192 for epoch 106
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 0.9381
# finished training epoch: 106...
#
# As a disciple of Jesus Christ, I testify that in the sacred name of Jesus Christ, amen.
#
#  The Holy Ghost is a personage of spirit as a result of the blessing of the Father and the Son. It is the Holy Ghost that reveals the word of God and the testimony of Jesus Christ, to testify, and to act in His name. We are blessed by the rock of angels to guide and bless the nations of the earth. We are blessed to be blessed by the seed of Abraham as far, to
# As a disciple of Jesus Christ, I testify in the sacred name of Jesus Christ, amen.
#
#  What a mighty force to be with you as we begin this great conference with a sacred obligation we could be there. I will present the General Authorities, Area Seventies, and General Officers of the Church for your sustaining vote.
#  Please express your support in the usual way wherever you may be. If you will be faithful, my message is a most precious and beautiful day of the Lord’s Church. And I pray for the
# As a disciple of Jesus Christ, I testify that God is our Father. I testify that He is our Savior and Redeemer of the human purpose. He is our Exemplar, our Redeemer, our Redeemer. Of His Atonement and Resurrection in the fulness of the Father, our Redeemer and Savior is the Redeemer, Savior of the world, "the most important event, and in all things, in all things, in all things, in all things, in all places of all things" (Mosiah 27:8).
#
#  Of the Quorum of the Twelve Apostles
#  Honoring covenants arms of the Savior and His holy work be established through the Atonement of Jesus Christ.
#  As we study the scriptures and listen to the sacred music of each of us, we can be blessed to know the Lord.
#  The Savior declared, "I will tell you in your mind and in your heart, by the Holy Ghost, which shall come upon
# As a disciple of Jesus Christ, I testify with all my heart that Jesus Christ lives. He is the Savior of the world. He lives and loves us. I so testify in the sacred name of the Lord Jesus Christ, amen.
#
#  I invite you to consider the Lord’s love for us. I testify that the Lord knows and is mindful of each of us. I joyfully bear witness in the sacred name of Jesus Christ, amen.
#
#  The Savior is the Son of God, the Father of our
# As a disciple of Jesus Christ, I testify that Jesus Christ is the Son of God, the Only Begotten Son, the Only Begotten in the flesh, was and is the Redeemer of the Father, and of His Son, who is our Savior and Redeemer. And I witness that He is our Redeemer. He lives and leads His Church. And I bear witness that He lives and that He will bless and keep His promises to us, the gift of grace and the blessing of His Son, Jesus
# As a disciple of Jesus Christ, I testify and pray that we may always have the Spirit of the Lord as we learn with His Spirit and feel the help spiritual preparation for His exceeding great and sacred promises made through Him.
#  I testify of the truth of the Savior’s Atonement and the redemption of all things from the beginning of Adam to the earth and to be born again.
#  As we strive to understand the divine nature within the covenant in our lives, we must press forward with faith by a living God.
#  In the
# As a disciple of Jesus Christ, I testify that Jesus Christ is "the light and the life of the world."26
#  I joyfully witness that Heavenly Father’s plan of happiness and peace will come "line upon line, precept upon the light of Christ, and becoming the pleasing of everlasting Redeemer." I described a fundamental principle Alma called "What is man to be" in His name, and exercise power from His Atonement. His influence and His healing attributes does not seem weakness now, either or small and sometimes difficult to think (see Mosiah
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
#
# 22:41:24 - epoch: 110/125
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 192 for epoch 110
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - loss: 0.8816
# finished training epoch: 110...
#
# As a disciple of Jesus Christ, I testify that the Savior lives and that all things are possible. I know that Jesus Christ is His Only Begotten Son, that Joseph Smith is the Son of God, the Only Begotten Son, The Prince of Peace, the Redeemer of the world, the Creator of all things and all things. And I witness and testimony of the Savior’s divinity and the reality of His Atonement, which is the Redeemer, our Redeemer and Savior of all of us. I witness that Jesus
# As a disciple of Jesus Christ, I testify with all my heart that Jesus Christ lives. I witness He will be spared from the grave and becoming a mighty change of heart and a love of God.
#  I testify that Jesus Christ is our Savior and Redeemer of the world, the Only Begotten Son of the Eternal Father, the Only Begotten of the Father, our Redeemer, the Only Begotten of the rock, who is the Saviour of all mankind, Jesus Christ, amen.
#
#  In the bone of our
# As a disciple of Jesus Christ, I testify and witness that Jesus is the Christ. And I testify that Jesus is the Christ, the Eternal God. He lives and leads His Church on the earth today. I so testify in the sacred name of Jesus Christ, amen.
#
#  The Church of Jesus Christ of Latter-day Saints is led by a sacred grove that has been a glorious and solemn day to mark the name of the Savior of mankind. The Church of Jesus Christ is central to God’s plan
# As a disciple of Jesus Christ, I testify that God is our Heavenly Father to restore us and always remember Him and to be prepared for and faithfully serve Him. I so testify in the sacred name of Jesus Christ, amen.
#
#  Our Heavenly Father is a God of God, and He is the Son of the living God, who is the head of that Church, and invoke the Holy Ghost.
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
#
# 22:41:46 - epoch: 112/125
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 192 for epoch 112
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - loss: 0.8461
# finished training epoch: 112...
#
# As a disciple of Jesus Christ, I testify that the Savior lives. And I testify that He is our Savior. He is our Savior. He is our Savior. Of Him I bear witness of these truths in the awe of the Holy Spirit. I pray for the help of the Holy Ghost as we consider together in the work of the Lord. I so testify in the sacred name of the Lord Jesus Christ, amen.
#
#  The Holy Ghost is the third member of the Godhead. He is
# As a disciple of Jesus Christ, I testify that if you and I are to serve His people who have fallen hands and honor, I promise you that you will be blessed for your children to see, and to do what is right and become better and spiritually able to stand firm and can receive and to build the kingdom of God.
#  I testify that Jesus Christ is our Savior. I testify that Jesus is the Christ. We are His Church through the fulness of times, and I testify of the living reality of the Father
# As a disciple of Jesus Christ, I testify with all my heart and soul that I am a witness upon all who have been called, even the Lord Jesus Christ, amen.
#
#  Prayer is communication as we learn to receive spiritual guidance through the Atonement of Jesus Christ.
#  My dear brothers and sisters, I am grateful for the opportunity to address you in this inspiring session of October conference. I am grateful for the opportunity to stand before you today with a greater sense of testimony and spiritual power. In the name of Jesus
# As a disciple of Jesus Christ, I testify that as we come unto Christ and make covenants with Him, we shall receive eternal life, His grace and Resurrection can cleanse and be good and through the atoning sacrifice and mission of the Savior’s Atonement. As we progress and choose diligently and press forward with God at the vital and cleansing power of the universal Atonement, we can be blessed to know how to "go forward" to fulfill the mission of the Lord’s house.
#  I testify and witness in the sacred name of Jesus Christ, amen.
#
# As a disciple of Jesus Christ, I testify in the sacred name of the Lord Jesus Christ, amen.
#
#  Of the Church, we are empowered to bless the lives of individual and family history work together as families and as individuals and families.
#  The sacrament is true, given, covenant, and promise an and true Church of Christ. And I witness that the authority of the restored gospel of Jesus Christ guides the blessings of the Savior’s restored Church. The spiritual gift of the Spirit of the Lord "is a shield of blessings
# As a disciple of Jesus Christ, I testify in the sacred name of the Lord Jesus Christ, amen.
#
#  What is the difference between our children or our children?
#  As a boy growing up in a house of God, one of the most poignant and valuable lessons of trust in the plan of happiness is to the Lord of the world, the Church of Jesus Christ, and the restored Church.
#  The importance of our duty in sacrament meetings is clear. We can become as a Zion nor with the ability to hear a
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
#
# 22:41:57 - epoch: 113/125
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 192 for epoch 113
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 0.8523
# finished training epoch: 113...
#
# As a disciple of Jesus Christ, I testify that the Savior is the Son of the living God, and I know that the tender mercies of the Lord are real and can bring even and the assurance of the Savior’s Atonement. As I now study and ponder the scriptures and hear the words of the Savior:
#  "And now, I would that ye should come unto the Lord as we also receive all the Holy Ghost" (Mosiah 3:17).
#  In a similar way we can learn to be obedient to the Lord’s doctrine,
# As a disciple of Jesus Christ, I testify that the Lord Jesus Christ is our Savior. I testify that the tender mercies of the Lord are available to all of us and that the Holy Ghost is true, that Jesus is the Christ, that this is His Church, restored in these latter days and that Jesus is the Christ. He lives and invites us to be true and faithful to the covenant of His work.
#  I invite you to consider how you should respond to this question and to ask your Heavenly Father, in
# As a disciple of Jesus Christ, I testify in the sacred name of Jesus Christ, amen.
#
#  The Sabbath of Promise is a key and a protection of truth and a protection to the world.
#  I have been blessed with the call and privilege from the President of the Church to speak to you and to all of the General Authorities. I have served in many capacities for you who have graduated or 14 years and more. I love and appreciate you, and I do it in the spirit of these things that they are true
# As a disciple of Jesus Christ, I testify that this is the Savior’s Church and the Savior’s gospel and the Lord’s Church. And I testify that the restored gospel of the Lord Jesus Christ is restored. He is the Light and Life of the World. He made the heavens and the earth for all of the General Authorities of the Church in these latter days. I so testify in the sacred name of Jesus Christ, amen.
#
#  The title of our president is a sacred place. I am grateful for this
# As a disciple of Jesus Christ, I testify that the Book of Mormon is the word of God. It is the keystone of the pattern by which we declare the everlasting gospel of Jesus Christ to the truth of the gospel of Jesus Christ.
#  The pattern is clear in the Lord’s message that He will come again and again through divine authority through the Holy Ghost. The Holy Ghost will be more than our own and through need. We will then be prepared to set aside what the Lord has given us to do. As
# As a disciple of Jesus Christ, I testify in the sacred name of the Lord Jesus Christ, amen.
#
#  Of all the things of the earth, President Russell M. Nelson, our Easter Sunday address moments ago quoted this day with a heartfelt prayer to President Howard W. Hunter through message. He stressed the importance of asking members of the First Presidency: "I have lived in the temple and have been a good example of the Gospel."
#  With the President of the Church and the only windows of our lives
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
#
# 22:42:07 - epoch: 114/125
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 192 for epoch 114
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 0.8284
# finished training epoch: 114...
#
# As a disciple of Jesus Christ, I testify that in the sacred name of Jesus Christ, amen.
#
#  I pray for the assistance of the Holy Ghost for me and for you as we rejoice together in the sacred name of Jesus Christ, amen.
#
#  My beloved brethren and sisters, I pray for the blessings of the Savior’s Atonement. I pray for the Spirit of the Lord to be with us.
#  I pray that the Holy Ghost will instruct and edify each of us. I know that God lives.
# As a disciple of Jesus Christ, I testify with all my heart and soul that Jesus is the Christ. He is our Savior, our Redeemer, and I are deeply one of the Only Begotten Son, our Redeemer and Redeemer. He is our Redeemer. I know He lives. And I pray that we will always have His Spirit to be with us and that He is our Savior, that we are willing to do so in His work to become more like Him. And I promise that as we continue in the
# As a disciple of Jesus Christ, I testify with His holy name, Jesus Christ, amen.
#
#  I desire to talk about the messages of these two servants of God who have answered the question, "I invite each of you to consider all the Priesthood Apostles in all the earth. I invite you to learn about the Restoration of the gospel of Abraham and the [Liahona]" and "come unto God and be perfected in him." The Savior has declared, "Ye shall be my people, and I will be your God."
# As a disciple of Jesus Christ, I testify and pray that the Lord is mindful of each of us that Jesus is the Christ, the Son of God, the Redeemer and Savior of the Living God (see D&C 46:6).
#  I pray that Jesus Christ is our Savior and Redeemer and Savior of the world, the Only Begotten Son of the Eternal Father, "the Only Begotten of the Father, he is the Only Begotten of the Father" (D&C 76:1).
#  I witness
# As a disciple of Jesus Christ, I testify that we do not need to be "chosen in and through the holy scriptures. We promise that the promised blessings that the Lord has shown to accomplish will become (see Abraham 1:22). And as we honor our covenants, we are promised that we will always have His Spirit to be with us (see John 14:26), and to bestow according to his deeds the Savior requires our declaration: "Behold, this is the spirit of revelation; yea, whatsoever things shall come that all thy Spirit ye are only
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 779ms/step - loss: 1.0701
# finished training epoch: 124...
#
# As a disciple of Jesus Christ, I testify that he lives, that Jesus is the Christ, and that we are led today to be born into the Church by a living prophet, President Gordon B. Hinckley. We are all our strength to follow Him and follow Him. We are to "come, and to [our] mother." He has "power to the faint, the blind,] and the life." He is not going "to hear and give [us].’"11. He is not to judge anyone to die but for all eternity.
# As a disciple of Jesus Christ, I testify that there is no other way or disappointment or disappointment or sorrow, for we are not shallow or relentless to bear than we are yet converted to the Spirit of Christ and gain a better sense of obedience and forgiveness to a troubled world.
#  It is not just the light to be restrained or a steep sin or a loved one or a type of regret, or to avoid them the consequences of disobedience and disobedience, while sometimes it is too often used to destroy our beliefs, the choices of our nations cause us to
# As a disciple of Jesus Christ, I testify that this is true, as I leave with you the mark Jesus walked.
#  "And when he was blind, he called unto him meat, even as he was healed, and with on the right, and took away his cross, and his disciples with his angels" (1 Ne. 9:11). We can show our testimonies "that [we] may conquer many of these things, lest we have the enemy of the devil, and we shall fall up to the flock of peace and joy! If we do not,
# As a disciple of Jesus Christ, I testify that there is a God willing to "rest in the land for death." He "giveth power unto the understanding" through faith everlasting salvation. His plan of redemption can save us from the sin of our immortal bodies and provide power to constant glory.
#  "For I, the Lord, give unto them a promise, the truth of it is not heard. … For he that is an Lord, he has given a promise." When we accept the message of the Restoration and our testimony and act by the
# As a disciple of Jesus Christ, I testify that laws change our thoughts, sicknesses, pain, and anguish for our transgressions. Paul counseled his Apostles that the Savior is with us always. As one final day, He has given us the way, as He has said to Peter, our Good Shepherd, to learn of Him and Their short little more. We have no less than they are yet.
#  I have of necessity frequently, my brethren, that some in you who are suffering, some minor to bear to God, I testify to you that
# As a disciple of Jesus Christ, I testify that no matter what has or may not be your death as it is my prayer, in the name of Jesus Christ, our Lord and Savior, amen.
#
#  We can and can stand by that to those who are not yet members or whose focus so in the past. Thank you for taking a personal experience in doing so each of us as prophets, seers, and revelators in our day as we listen to the messages in the sacred name of the Lord Jesus Christ, and of whom it has
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
#
# 23:14:41 - epoch: 125/125
# File 'speakers/patrick-kearon.txt' found locally. Using it.
# Using sequence length: 192 for epoch 125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 786ms/step - loss: 1.0916
# finished training epoch: 125...
#
# As a disciple of Jesus Christ, I testify that in His willing submission to the Father’s plan, He can turn from the despair of broken hearts. You can make mistakes, you will never give up.
#  The Apostle Paul’s entire experience has provided guidelines to the vast Priesthood Services President with the Manti Temple. He is a man of God and a people who are willing to sacrifice for their children and their country. He has urged that decisions determine destiny. He has declared:
#  "For God hath not given us the spirit of
# As a disciple of Jesus Christ, I testify that as you and I observe the Savior’s name, His gospel provides answers to life’s greatest questions: "And if it so be that you should labor all your days in crying repentance unto this people, and bring, save it be one soul unto me, how great shall be your joy with him in the kingdom of my Father!
#  "And now, if your joy will be great with one soul that you have brought unto me into the kingdom of my Father, how great will be your joy if you should
# As a disciple of Jesus Christ, I testify that in Their atoning mercy, all things are possible; for they are saved. We are sons of God and therefore to live the lives of ourselves. We are to be a blessed people of His kingdom. We are not left alone. It is not to let those with us who feel alone and who listen to the counsel of our Heavenly Father and of the Savior for us. And we must all be prone to hide our problems, to let them know that the Savior has no aid to prevent
# As a disciple of Jesus Christ, I testify that He does love us and will find us the way to follow. He has commanded us to love our neighbors and those for whom we have promised us.
#  We are children of God.
#  Jesus Christ is the Great One of His heaven speaking to men whereby we must not after our acts of kindness and our good, even God’s laws and commandments. His plan provides answers to the ultimate answer to the question posed by Him, who taught, "What manner of persons ought ye to be?
# As a disciple of Jesus Christ, I testify that there is a Supreme Plan, even the only way for us is not all necessary.
#  No greater joy comes from the decision of the Lord to change and respond with the merciful life of the Godhead to celestial glory! Then Jesus was Peter, "I will make you fishers so now that my grace is done." He then fed us up. Suffering may ultimately come from those who attack us.
#  When I reflect upon the world, I have thought of the significance of the words found
# As a disciple of Jesus Christ, I testify that as we come to the Savior’s coming, we need not gaze in His presence when there is today the faithful that "He must hold upon Jesus the mediator both power of His daughters." The Fall was to come into a "last that salvation" or "a state of Christianity" and all else had no people.
#  We often take opportunity for the Savior’s promise to His Father in Heaven who loves us perfectly and are perfect examples, but yet we can find healing through the Atonement of
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
#
#
# Final epoch (125) reached.
# Model saved as models/conf-t5-100e_curric_kearon-t1-25e.keras

# %%
model.load_weights("models/conf-t5-100e.keras")
for temp in [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]:
    produce_sample(model, vectorize_layer, vocabulary, temp, num_epochs_total - 1, 'What does the fox say?')

# %%
final_seed_text = "The world seemed like such a peaceful place until the tree of life was discovered in London."
model_path = 'models/'
response_path = 'saved_files/responses/'

base_filename = f'conf-t{main_test_num}-{base_epochs}e_{learn_type}'
speaker_file_end = f'-t{transfer_test_num}-{transfer_epochs}e'

keras_ext = '.keras'
response_ext = '.txt'

# %%
def save_responses(model_file, response_file, seed_text):
    model.load_weights(model_file)
    for temp in [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]:
        response = \
            produce_sample(model,
                vectorize_layer,
                vocabulary,
                temp,
                num_epochs_total - 1,
                seed_text,
                length=1000,
                do_print=False)
        with open(response_file, 'a') as f:
            f.write(f"Temp: {temp}\n")
            f.write(response)
            f.write('\n\n')
    print(f"Response saved as {response_file}")

# %%
for speaker in speakers:
    last_name = '_' + speaker.split('-')[-1]
    speaker_keras_filename = model_path + base_filename + last_name + speaker_file_end + keras_ext
    speaker_response_filename = response_path + base_filename + last_name + speaker_file_end + response_ext
    save_responses(speaker_keras_filename, speaker_response_filename, final_seed_text)
# Out:
# Response saved as saved_files/responses/conf-t4-200e_curric_bednar-t1-50e.txt
# Response saved as saved_files/responses/conf-t4-200e_curric_uchtdorf-t1-50e.txt
# Response saved as saved_files/responses/conf-t4-200e_curric_holland-t1-50e.txt
# Response saved as saved_files/responses/conf-t4-200e_curric_nelson-t1-50e.txt
# Response saved as saved_files/responses/conf-t4-200e_curric_monson-t1-50e.txt
# Response saved as saved_files/responses/conf-t4-200e_curric_kearon-t1-50e.txt

# %%
general_keras_filename = model_path + base_filename + keras_ext
general_response_filename = response_path + base_filename + response_ext
save_responses(general_keras_filename, general_response_filename, final_seed_text)
# Out:
# Response saved as saved_files/responses/conf-t4-200e_curric.txt
