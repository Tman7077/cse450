# %% [markdown]
# ### Setup

# %%
# Import libraries

# import contextlib
import gc
# import io
# import numpy as np
import os
# import random
import re
import string
import time

os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"

import tensorflow as tf
from tensorflow.keras import Sequential # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D, StringLookup, TextVectorization # type: ignore

# NOTE: testing
# print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2025-03-26 18:10:12.691039: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-26 18:10:12.701409: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743034212.713304   29607 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743034212.717057   29607 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-26 18:10:12.729238: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
RESTART = False
TRANSFER = False
if TRANSFER:
    BATCH_SIZE = 64
    LEARNING_RATE = 0.00005
else:
    BATCH_SIZE = 128
    LEARNING_RATE = 0.0005
# BATCH_SIZE = 64
EPOCH_TO_PICKUP = 42
PATH = ''
VOCAB_SIZE = 8192
SEQUENCE_LENGTH = 128
BUFFER_SIZE = 10000
TEACHER_FORCED = False

# %% [markdown]
# ### Text Processing

# %%
def preprocess_text(text):

    # fix quotes
    text = text.replace("“", "\"")
    text = text.replace("”", "\"")

    # Replace any capital letter at the start of a word with ^ followed by the lowercase letter
    text = re.sub(r"(?<![a-zA-Z])([A-Z])", lambda match: f"^{match.group(0).lower()}", text)

    # Replace all other capital letters with lowercase
    text = re.sub(r"([A-Z])", lambda match: f"{match.group(0).lower()}", text)

    # Replace whitespace characters with special words
    text = re.sub(r"(\t)", r" zztabzz ", text)
    text = re.sub(r"(\n)", r" zznewlinezz ", text)
    text = re.sub(r"(\s)", r" zzspacezz ", text)

    # Split before and after punctuation
    for punctuation in string.punctuation:
        text = text.replace(punctuation, f" {punctuation} ")

    return text

def postprocess_text(text):

    # Replace special words with whitespace characters
    text = text.replace("zztabzz", "\t")
    text = text.replace("zznewlinezz", "\n")
    text = text.replace("zzspacezz", " ")

    # Remake capital letters at beginning of words
    text = re.sub(r"\^([a-z])", lambda match: f"{match.group(1).upper()}", text)

    text = text.replace("^", "")

    return text

def getMyText(filename='all_talks_2000.txt'):
    file_name = filename
    local_dir = 'saved_files'
    local_path = os.path.join(local_dir, file_name)

    try:
        # Ensure the directory exists
        if not os.path.exists(local_dir):
            os.makedirs(local_dir)

        # Check if the file exists locally
        if os.path.exists(local_path):
            print(f"File '{file_name}' found locally. Using it.")
        else:
            print(f"File '{file_name}' not found.")
            return

        # Read the file's contents
        with open(local_path, 'rb') as file:
            text = file.read().decode(encoding='utf-8')

        return preprocess_text(text)

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
if RESTART:
  vocab_text = getMyText()

  ### Make vocabulary (Adapted from TensorFlow word embedding tutorial)
  # Use the text vectorization layer to normalize, split, and map strings to
  # integers. Note that the layer uses the custom standardization defined above.
  # Set maximum_sequence length as all samples are not of the same length.
  vectorize_layer = TextVectorization(
      standardize='lower',
      split='whitespace',
      max_tokens=VOCAB_SIZE,
      output_mode='int',
      )
  # Make a text-only dataset (no labels) and call adapt to build the vocabulary.
  vectorize_layer.adapt([vocab_text])
  vocabulary = vectorize_layer.get_vocabulary()

  ### Save Vocabulary
  with open(PATH + "vocabulary.txt", "w") as file:
    for word in vocabulary:
        file.write(word + "\n")
else:
  ### Load Saved Vocabulary
  with open(PATH + "vocabulary.txt", "r") as file:
      vocabulary = [word.strip() for word in file.readlines()]
      vocabulary = vocabulary

  vectorize_layer = TextVectorization(
      vocabulary=vocabulary,
      standardize='lower',
      split='whitespace',
      max_tokens=VOCAB_SIZE,
      output_mode='int',
      )
  
# NOTE: testing
# print(vocabulary[:20])
# print(vocabulary[-20:])
# Out:
# I0000 00:00:1743034219.537008   29607 gpu_process_state.cc:201] Using CUDA malloc Async allocator for GPU: 0
# I0000 00:00:1743034219.537194   29607 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13499 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# This function will generate our sequence pairs:
def split_input_target(sequence):
    input_ids = sequence[:-1]
    target_ids = sequence[1:]
    return input_ids, target_ids

# This function will create the dataset
def text_to_dataset_teacher_forced(text, *args, **kwargs):
  
    all_ids = vectorize_layer(text)
    ids_dataset = tf.data.Dataset.from_tensor_slices(all_ids)
    del all_ids
    sequences = ids_dataset.batch(SEQUENCE_LENGTH+1, drop_remainder=True)
    del ids_dataset

    # Call the function for every sequence in our list to create a new dataset
    # of input->target pairs
    dataset = sequences.map(split_input_target)
    del sequences

    return dataset

def text_to_dataset_curriculum_learning(text, initial_seq_length=24, max_seq_length=SEQUENCE_LENGTH*1.5, growth_factor=1.025, current_epoch=0):
    """
    Implements curriculum learning by gradually increasing sequence length as training progresses.
    
    Parameters:
        text (str): The input text data.
        initial_seq_length (int): The starting sequence length.
        max_seq_length (int): The maximum sequence length.
        growth_factor (float): The rate at which sequence length increases per epoch.
        current_epoch (int): The current training epoch.
    
    Returns:
        tf.data.Dataset: The processed dataset with gradually increasing sequence length.
    """
    # Compute the sequence length dynamically based on the current epoch
    sequence_length = min(int(max_seq_length), int(initial_seq_length * (growth_factor ** current_epoch)))
    
    print(f"Using sequence length: {sequence_length} for epoch {current_epoch + 1}")
    
    # Convert text to token IDs
    all_ids = vectorize_layer(text)
    ids_dataset = tf.data.Dataset.from_tensor_slices(all_ids)
    del all_ids

    # Create sequences with the dynamically determined length
    sequences = ids_dataset.batch(sequence_length, drop_remainder=True)
    del ids_dataset

    # Create input-target pairs (teacher forcing still applies, but curriculum learning controls sequence length)
    dataset = sequences.map(split_input_target)
    del sequences

    return dataset


def text_from_ids(ids):
    text = ''.join([vocabulary[index] for index in ids])
    return postprocess_text(text)

def setup_dataset(dataset):
    dataset = (
      dataset
      .shuffle(BUFFER_SIZE)
      .batch(BATCH_SIZE, drop_remainder=True)
      .prefetch(tf.data.experimental.AUTOTUNE))
    return dataset

# %%
if TEACHER_FORCED:
    learning_mode_fn = text_to_dataset_teacher_forced
else:
    learning_mode_fn = text_to_dataset_curriculum_learning

vocabulary_adjusted = vocabulary
vocabulary_adjusted[0] = '[UNK]'
vocabulary_adjusted[1] = ''
words_from_ids = tf.keras.layers.StringLookup(vocabulary=vocabulary_adjusted, invert=True)

if RESTART:
  vocab_ds = learning_mode_fn(vocab_text)
  for input_example, target_example in vocab_ds.take(1):
    print("Input: ")
    print(input_example)
    print(text_from_ids(input_example))
    print(words_from_ids(input_example))
    print("Target: ")
    print(target_example)
    print(text_from_ids(target_example))
    
  vocab_ds = setup_dataset(vocab_ds)

  dataset = vocab_ds
  del vocab_text
  del vocab_ds
else:
  dataset = learning_mode_fn(getMyText())
  dataset = setup_dataset(dataset)
# Out:
# File 'all_talks_2000.txt' found locally. Using it.
# Using sequence length: 24 for epoch 1

# %% [markdown]
# ### Model Building

# %%
# Create our custom model. Given a sequence of characters, this
# model's job is to predict what character should come next.
class ConferenceTextModel(tf.keras.Model):

  # This is our class constructor method, it will be executed when
  # we first create an instance of the class
  def __init__(self, vocab_size, embedding_dim, rnn_units):
    super().__init__()

    # Our model will have three layers:

    # 1. An embedding layer that handles the encoding of our vocabulary into
    #    a vector of values suitable for a neural network
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)

    # 2. A GRU layer that handles the "memory" aspects of our RNN. If you're
    #    wondering why we use GRU instead of LSTM, and whether LSTM is better,
    #    take a look at this article: https://datascience.stackexchange.com/questions/14581/when-to-use-gru-over-lstm
    #    then consider trying out LSTM instead (or in addition to!)
    self.lstm1 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
    self.lstm2 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
    self.lstm3 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)


    self.hidden1 = tf.keras.layers.Dense(embedding_dim*64, activation='relu')
    self.hidden2 = tf.keras.layers.Dense(embedding_dim*16, activation='relu')

    # 3. Our output layer that will give us a set of probabilities for each
    #    character in our vocabulary.
    self.dense = tf.keras.layers.Dense(vocab_size)

    # Define default initial states as None (they will be created once)
    self.initial_states = None

  def get_initial_states(self, batch_size):
    """Generate initial states once per batch"""
    return [
        [tf.zeros([batch_size, self.lstm1.units]), tf.zeros([batch_size, self.lstm1.units])],
        [tf.zeros([batch_size, self.lstm2.units]), tf.zeros([batch_size, self.lstm2.units])],
        [tf.zeros([batch_size, self.lstm3.units]), tf.zeros([batch_size, self.lstm3.units])],
    ]
  
  # This function will be executed for each epoch of our training. Here
  # we will manually feed information from one layer of our network to the
  # next.

  def call(self, inputs, states=None, return_state=False, training=False):
    x = self.embedding(inputs, training=training)
    batch_size = tf.shape(inputs)[0]

    # Use pre-defined function to get initial states
    if states is None:
        states = self.get_initial_states(batch_size)

    # LSTM layers process input sequentially
    x, state_h_1, state_c_1 = self.lstm1(x, initial_state=states[0], training=training)
    states_out_1 = [state_h_1, state_c_1]

    x, state_h_2, state_c_2 = self.lstm2(x, initial_state=states[1], training=training)
    states_out_2 = [state_h_2, state_c_2]

    x, state_h_3, state_c_3 = self.lstm3(x, initial_state=states[2], training=training)
    states_out_3 = [state_h_3, state_c_3]

    states_out = [states_out_1, states_out_2, states_out_3]

    x = self.hidden1(x, training=training)
    x = self.hidden2(x, training=training)
    x = self.dense(x, training=training)

    return (x, states_out) if return_state else x
  
'''
----------------------------------------------------------------------------------------------------
'''
# Here's the code we'll use to sample for us. It has some extra steps to apply
# the temperature to the distribution, and to make sure we don't get empty
# characters in our text. Most importantly, it will keep track of our model
# state for us.

class OneStep(tf.keras.Model):
  def __init__(self, model, vectorize_layer, vocabulary, temperature=1):
    super().__init__()
    self.temperature=temperature
    self.model = model
    self.vectorize_layer = vectorize_layer
    self.vocabulary = vocabulary

    # Create a mask to prevent "" or "[UNK]" from being generated.
    skip_ids = StringLookup(vocabulary=list(vocabulary))(['', '[UNK]'])[:, None]
    sparse_mask = tf.SparseTensor(
        # Put a -inf at each bad index.
        values=[-float('inf')]*len(skip_ids),
        indices = skip_ids,
        # Match the shape to the vocabulary
        dense_shape=[len(vocabulary)])
    self.prediction_mask = tf.sparse.to_dense(sparse_mask,validate_indices=False)

  @tf.function
  def generate_one_step(self, inputs, states=None):
    # Convert strings to token IDs.
    input_ids = self.vectorize_layer(inputs)

    # Run the model.
    # predicted_logits.shape is [batch, char, next_char_logits]
    predicted_logits, states =  self.model(inputs=input_ids, states=states,
                                          return_state=True)
    del input_ids
    # Only use the last prediction.
    predicted_logits = predicted_logits[:, -1, :]
    predicted_logits = predicted_logits/self.temperature

    # Apply the prediction mask: prevent "" or "[UNK]" from being generated.
    predicted_logits = predicted_logits + self.prediction_mask

    # Sample the output logits to generate token IDs.
    predicted_ids = tf.random.categorical(predicted_logits, num_samples=1)
    del predicted_logits
    predicted_ids = tf.squeeze(predicted_ids, axis=-1)

    # Return the characters and model state.
    return words_from_ids(predicted_ids), states

'''
----------------------------------------------------------------------------------------------------
'''

def produce_sample(model, vectorize_layer, vocabulary, temp, epoch, prompt, length=200, do_print=True):
  one_step_model = OneStep(model, vectorize_layer, vocabulary, temp)
  states = None
  next_char = tf.constant([preprocess_text(prompt)])
  result = [tf.constant([prompt])]

  for _ in range(length):
    next_char, states = one_step_model.generate_one_step(next_char, states=states)
    result.append(next_char)

  result = tf.strings.join(result)
  if do_print:
    print(postprocess_text(result[0].numpy().decode('utf-8')))
    print('Epoch: ' + str(epoch) + '\n', file=open(PATH + 'tree.txt', 'a'))
    print('Temp: ' + str(temp) + '\n', file=open(PATH + 'tree.txt', 'a'))
    print(postprocess_text(result[0].numpy().decode('utf-8')), file=open(PATH + 'tree.txt', 'a'))
    print('\n\n', file=open(PATH + 'tree.txt', 'a'))
    del states
    del next_char
    del result
  else:
    return postprocess_text(result[0].numpy().decode('utf-8'))

# %%
embedding_dim = 128
rnn_units = 512
model = ConferenceTextModel(VOCAB_SIZE, embedding_dim, rnn_units)

# NOTE: testing
# Verify the output of our model is correct by running one sample through
# This will also compile the model for us. This step will take a bit.
# for input_example_batch, target_example_batch in dataset.take(1):
#     example_batch_predictions = model(input_example_batch)
#     print(example_batch_predictions.shape, "# (BATCH_SIZE, sequence_length, VOCAB_SIZE)")

# NOTE: more testing
# model.summary()

# %% [markdown]
# ### Model Training

# %%
if TRANSFER:
  model_file_to_load = "conf-test2-400ep.keras"
  model.load_weights(PATH + 'models/' + model_file_to_load)

# %%
early_stop = EarlyStopping(
    monitor='loss',
    min_delta=0.01,
    patience=5,
    restore_best_weights=True
)
loss = tf.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=opt, loss=loss)

base_epochs = 100
transfer_epochs = 0
num_epochs_total = base_epochs + transfer_epochs
main_test_num = 5
transfer_test_num = 1

if TEACHER_FORCED:
    learn_type = 'teacher'
else:
    learn_type = 'curric'

if RESTART:
  start_epoch = 0
else:
  start_epoch = EPOCH_TO_PICKUP

# %%
def run(name='all_talks_2000'):
  stop_training = False
  for e in range(start_epoch, num_epochs_total):
    if stop_training:
      print(f"Early stopping triggered at epoch {e + 1}. Exiting training.")
      break
    success = False
    while(success == False):
      try:
        print(f'{time.strftime("%H:%M:%S", time.localtime(time.time()))} - epoch: {e + 1}/{num_epochs_total}')
        new_text = getMyText(f'{name}.txt')
        # dataset = learning_mode_fn(new_text, current_epoch=e)
        dataset = learning_mode_fn(new_text, growth_factor=1.05, current_epoch=e)
        # print("Dataset created...")
        del new_text
        dataset = setup_dataset(dataset)
        # print("Dataset set up...")
        model.optimizer.learning_rate.assign(LEARNING_RATE*(0.99**e))
        # print("Model is fitting...")
        model.fit(dataset, epochs=1, verbose=1, callbacks=[early_stop])
        if early_stop.stopped_epoch > 0:
          stop_training = True
        print(f"finished training epoch: {e + 1}...\n")
        del dataset
        for temp in [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]:
          produce_sample(model, vectorize_layer, vocabulary, temp, e, 'As a disciple of Jesus Christ, I testify')
        print("\nsamples produced...")
        gc.collect()
        print("garbage collected...")
        tf.keras.backend.clear_session()
        print("session cleared (to save memory)...\n")
        success = True
      except:
        gc.collect()
        tf.keras.backend.clear_session()
        try:
          del dataset
        except:
          print("dataset was not produced or has already been deleted")
        print("retrying epoch: " , e + 1)

  print(f'\nFinal epoch ({num_epochs_total}) reached.')
  filename = f'models/conf-t{main_test_num}-{base_epochs}e_{learn_type}'
  if base_epochs < num_epochs_total:
    filename += f'_{name.split("-")[-1]}-t{transfer_test_num}-{transfer_epochs}e'
  filename += '.keras'
  model.save(filename)
  print(f"Model saved as {filename}")

# %%
# NOTE: testing
# dataset = learning_mode_fn(getMyText(), growth_factor=1.05, current_epoch=43)

# %%
run() # just once, for training from scratch
# Out:
# 18:10:45 - epoch: 43/100
# File 'all_talks_2000.txt' found locally. Using it.
# Using sequence length: 186 for epoch 43
# I0000 00:00:1743034252.312030   29771 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  43/333 ━━━━━━━━━━━━━━━━━━━━ 1:36 332ms/step - loss: 6.5525

# %%
speakers = ['david-a-bednar', 'dieter-f-uchtdorf', 'jeffrey-r-holland', 'russell-m-nelson', 'thomas-s-monson', 'patrick-kearon']
for speaker in speakers:
  filename = f'speakers/{speaker}'
  run(filename)
# Out:
# epoch: 201/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 200
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 228ms/step - loss: 0.4447
# finished training...
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. This is their instruction, individually and collectively. He has called us and directed our prophet to serve President Hinckley. There is nothing more important than honoring the covenants it gives a full measure of love for the Lord and His children. Please remember this sure evening. We have heard again some of my most poignant missionary experiences. I don’t know about that, but I do
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the present prophet of God. I so testify in the name of Jesus Christ, amen.
#
#  I hope you had a burning in your heart because you are lost, and you are not tired, now and one. They have within your
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. The Lord instructed Emma to expound the scriptures, to exhort the Church, to receive the Holy Ghost, and to spend her time "learning much." Leave the past to make judgment as an increased ability to distinguish truth? While living in a time of turmoil, disaster, and life, we do not need to worry about appealing or use or abuse. Beware of such, righteous
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. The Savior and His Church have been the means for final event, a magnificent era of organizing and approved by the Church, and sons of Heavenly Father’s daughters on the earth by holy angels. With the presiding officers of the Church of Jesus Christ, we understand and affirm that "in the celestial glory there are three heavens or degrees; and in order to obtain the
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. This is their instruction, individually and collectively. He has called us and directed our prophet to serve President Hinckley.
#  Despite our mistakes, actions, and tribulations, we have a sacred grove of people. Of these truths I solemnly bear witness in the name of Jesus Christ, amen.
#
#  We declare to the world that the fulness of the gospel of Jesus Christ
# As a disciple of Jesus Christ, I testify to you that our love of God, our meekness in our hearts, and prompt our efforts to protect us from evil. I thank God for temples. I know Joseph Smith is a prophet of God. The spiritual nature of his authority is found in the Epistle of James: "They did not send the name of the voice because of it." (Ether 12:4.)
#  The question asked by this Relief Society president applies to the United States and Canada. However, this gospel culture
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 202/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 201
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - loss: 0.2887
# finished training...
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. The Lord instructed Emma to expound the scriptures, to exhort the Church, to receive the Holy Ghost, and to spend her time "learning much." Leave the past to make judgment as an increased ability to distinguish truth? Is it in program growth healing? I must start today to discuss the sanctity of life. I was only six into New York for the winter.
# As a disciple of Jesus Christ, I testify to you that our time had not been out of state but of the Holy Ghost. By understanding and living the commandments of God, we will rejoice in Him when we draw upon the powers of heaven planted in our lives is the teaching of eternal truth with constant conviction. Yet we know of your duty and the will of your Father in Heaven for success. If you try with all your heart to have your heart strong and firm on his moral obligation, if there could turn something inside each of you
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. Joseph Smith is the prophet through whom the Lord restored the gospel in these latter days. President Ezra Taft Benson is the present prophet of God. In the name of Jesus Christ, amen.
#
#  In the first section of the Doctrine and Covenants, we read the Lord’s promise:
#  "Hearken, O ye people of my church, saith the voice
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. The Lord instructed Emma to expound the scriptures, to exhort the Church, to receive the Holy Ghost, and to spend her time "learning much." Leave the past to share the feelings of the Father for it and for you, for whom you have listened today as His servant, whose name is Their help. It is evidence that there are no assigned subjects, no
# As a disciple of Jesus Christ, I testify to you that our love of the Lord [and our brothers] in ourselves. Indeed, the Lord is actively directing the priesthood. The Master used this instruction: "I the Lord cannot look upon sin with the least degree of allowance;
#  "Nevertheless, he that repents and does the commandments of the Lord shall be forgiven."13
#  "And as often as my people repent will I forgive them their trespasses against me."14
#  Repentance and divine grace resolve the effects of sin and, for the end when
# As a disciple of Jesus Christ, I testify to you that our love of God, we become clean when we act in His service.
#  For some of you it is not our own mortal existence, and it was intended that man more than me now to serve God.
#  And the Lord in his poem from First Vision: "He had a divinely appointed president of the Priesthood and 12 General Authorities and auxiliary leaders and with faithful members of the Church throughout the world. I pray for a blessing of preparation for this conference.
#
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 203/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 202
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - loss: 0.2130
# finished training...
# As a disciple of Jesus Christ, I testify to you that our love is in our hearts. Let us pray for the health and the healing of the Spirit in our home. We must also allow ourselves to experience the blessings of a loving family in the home.
#  I know that living the principles of the gospel are baptism by immersion for the remission of sins (see As You Forgive Our Brethren," Ensign, Jan. 1976, pp. 10–11).
#  Our further message emphasizes having eternity in the great Second Coming of the Lord.
# As a disciple of Jesus Christ, I testify to you that our love is in our hearts. Let us pray for the gifts of His Spirit. We will need help, but we must also be merciful; we do not impart knowledge to our Heavenly Father, in the way we should come.
#  Through centuries of time, those who received Christ slowly for sign as we fully turn our hearts and look forward to those around us. May He bless us as we strive to live the greatest joy we experience. It does not mean you have felt support
# As a disciple of Jesus Christ, I testify to you that our wondrous perspective and trust in God will strengthen our faith in Heavenly Father and His holy Son, Jesus Christ, and feel secure in their hearts.
#  This is a time when you are becoming more like Him.
#  I bear my special witness that Jesus Christ lives. He is the shepherd of the lost sheep, the mighty Jehovah sent forth to declare, "Visit the house of each member, and exhort them to pray [for his family] and many others to their own happiness
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. They provide us direction. The Lord has said concerning us of this Church that our a spark of faith in the Lord are extended to all who seek, allow, inspire, and bear testimony to them.
#  - Strengthening priesthood example can edify and frustrate the home.
#  - The priesthood is for the benefit of all members of the Church. To magnify them, is to
# As a disciple of Jesus Christ, I testify that "peaceable followers of Christ" will find personal peace in this life and a glorious heavenly reunion. I bear a sure witness of the Savior’s divinity and the reality of His Atonement. He is our Savior and Redeemer. In the name of Jesus Christ, amen.
#
#  Brigham Young once counseled us to use the scriptures as follows:
#  "Do you read the Scriptures, my brethren and sisters, as though you were writing them a thousand, two thousand, or five thousand years ago? I
# As a disciple of Jesus Christ, I testify that "peaceable followers of Christ" will find personal peace in this life and a glorious heavenly reunion. I bear a sure witness of the Savior’s divinity and the reality of His Atonement. He is our Savior and Redeemer. In the name of Jesus Christ, amen.
#
#  Words set a tone. They voice our testimony of the two witnesses and one who knew what we know.
#  Everyone who prayed and sacrificed most accepted President Thomas S. Monson has said so often: "Now,
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 204/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 203
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 223ms/step - loss: 0.1655
# finished training...
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I testify of Him, and of His Atonement, keeping His commandments, and honoring covenants. But even those with the necessities of life are assured certain conditions for both such application as this statement from section 121 of the Doctrine and Covenants:
#  "And in the latter times to the priesthood, covenant belonging,
#
# As a disciple of Jesus Christ, I testify to you that our love of God, our meekness in our hearts, and prompt our efforts to protect us from evil. I thank him for the untold things he did, to take counsel from vision, knowing that his prayers were heard, and he that believeth not shall be lifted up at the last day" (Alma 37:37).
#  The second great example is the reality of the resurrection, and to come forth to life eternal is the presence of the devil. (See Moses 4:6.)
#  Perhaps when we
# As a disciple of Jesus Christ, I testify to you that our love of God, we become clean when we act in His service.
#  For some of you it is wonderful.
#  The Primary institution of [operations] has an advantage of the essential needs of the full-time missionaries and work in family home evening and our most appropriate information.
#  Last year the program changes today, I have observed that during 1998 I have visited many individuals with whom I pay tribute to their own heritage from women of the world as they have been counseled and encouraged
# As a disciple of Jesus Christ, I testify with my heart and soul that he, according to the power of the Melchizedek Priesthood, moved upon by the Father and the Savior that had come into his life and the lives of others, has given him the spirit of giving sublime courage and determination to forgive and to ask for forgiveness. Effort is required and a worthy purpose is to help us feel the peace that comes from following the Savior and strive towards His work.
#  We need to place for our neighborhoods, communities, or wherever mortals themselves with our
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I testify that the prophets restored priesthood and … priesthood keys necessary for the ordinances of salvation "upon the merits of him who is mighty to save" in the process of repentance, then from the living Water and by the Light of Christ.
#  I pray that we will take full advantage of every opportunity to regularly
# As a disciple of Jesus Christ, I testify to you that our love of God, our meekness in submission of the Spirit of the Lord, a greater influence in our lives, or the happiest way in our shared faith. With his permission I quote from a letter he wrote to me:
#  "I was born into the Church and was taught the gospel at my mother’s knee. Through her diligence and perseverance, she kindled a small family whom I knew nothing about. Oh, what a mighty group.’ She was up with her tears, her eyes filling
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 205/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 204
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - loss: 0.1386
# finished training...
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I promise as you follow Him and help others along the path of faith and learn how we can be cleansed of our sins and then make our hearts clean, true, prayerful, and constantly doing.
#  Years ago, I received a phone call telling me of a friend’s death in an accident. I was sitting in
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I promise as you follow Him and help others along the path of faith and learn how we can be cleansed of our sins and then respond to personal revelation.
#  President John Taylor cautioned us, "If you do not magnify your callings, God will hold you responsible for those whom you might have saved had
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I promise as you follow Him and help others along the path of faith and learn the commandments, then we may gain hope for things we can not do.
#  The Savior said, "Take, eat. … But I have a little moving around [for] the liberty fall; for friends who have little interest.
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On, following the principle, the Holy Bible and the Book of Mormon: Another Testament of Jesus Christ provide spiritual guidance and teaching from Jesus Christ in the scriptures. May God bless us with faith in Him who He is, for the sacrifices and lengthened out to Carthage on the eve of His betrayal. Following the Passover supper, He instructed and prepared the sacrament of the
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ.
#  How could any member fall the turn and look beyond the mark? Because of their conviction of God’s love, father is a recurring link to the pure love of Christ. However, I warn you, a new bishop, say, "Wait a minute! That is my problem. All of you are familiar with the story. Momentum followed the Winter Olympics. All four of the wheels occupied during the
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. The Savior and His Church have been restored to bless all of God’s children. I so testify in the sacred name of Jesus Christ, amen.
#
#  We take whatever the standards we have described in the scriptures. The Prophet Joseph Smith taught that "the Priesthood is an everlasting principle, and existed with God from eternity, and will to eternity, without beginning
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 206/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 205
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - loss: 0.1134
# finished training...
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, clearly, get more and more humble to the Lord. … And in this awful state we shall not dare to look up to our God" (Alma 12:14). There are many prepared in this conference not far as it has since the world began. As the early Apostles followed
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, clearly, get back on course. And we can do so much more.
#  Many years ago I was touched by a story that was designed as a career for me to read in a newspaper assignment when I was assigned to give my first talk. I called him. I baptized
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, clearly, get more and more humble to the Lord. … And in this awful state we shall not dare to look up to our God" (Alma 12:14). There are many prepared in this conference not far as it has since the world began. As the early Apostles followed
# As a disciple of Jesus Christ, I testify with my grief and deep despair that expanded us toward them.
#  Faith and repentance lead to the purifying and the sanctification of our souls. And it is Christ’s blood, wondrous beyond our comfort, and the sacrament covenant begins to prepare us to stand together as bearers of His holy priesthood. In the name of Jesus Christ, amen.
#
#  In God’s eternal plan, salvation is an individual matter; exaltation is a family matter.
#  Gratefully we welcome Elder D. Todd Christofferson to the Quorum of
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we do more than anything else we will ever know.
#  This important effort is my prayer this morning as we open this great conference. I also witness that our Heavenly Father and His Beloved Son, Jesus Christ, live. To be engaged in Their service is one of the greatest
# As a disciple of Jesus Christ, I testify to you that our love is in our hearts, each and every day we answer the enticings of the arm.
#  The Apostle Paul lists six attributes of a believer, generosity, tolerance, shame, and even tragedy. None of these can, even when attained the great glory made possible by the Atonement wrought by Jesus Christ and His Atonement. Salvation is taught in the scriptures and by the new and simple prophets, including members of the Church, including members of the Church whose divine doctrines and policies have the
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 207/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 206
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - loss: 0.1028
# finished training...
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, clearly, get back on course. And we know that He wants us to seek that trust. I promise
#  "Behold, my witness that speaketh lies, and teach all nations, baptizing them in the name of the Father, and of the Son, and of the Holy Ghost:
#
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, clearly, get more and more humble to the Lord. … With proper authority we can build into your personal lives the blessings for your life.
#  You who are wives and mothers are the anchors of the family. You bear the children. What an enormous and sacred responsibility that is.
# As a disciple of Jesus Christ, I testify to you that our wondrous perspective and trust in God always bless us with the companionship of the Holy Ghost (see D&C 8:2). As we profess truth rather than admonish, exhort, or simply share interesting experiences, we invite the Holy Ghost to confirm the specific question about whether we will serve him faithfully and well as we wish for."
#  And then he surprised the bishop with a phone call. Inexperienced music is not being dropped to the "one thing" or "how foolish, really mean, or
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On, following the principle, the Holy Ghost will have given us inspiration and revelation in time and in diverse places. It’s an example of that shows interest in the scriptures which has always kept those same blessings and taught how their actions in that home simply trusting in our Heavenly Father.
#  For some of you, a man, may be your friend and our loving friend. Brethren, we need to instruct
# As a disciple of Jesus Christ, I testify that neither Satan nor any other power can weaken or destroy your growing influence. …
#  "You cannot do wrong and reflect on yourselves in any way to experience spiritual knowledge and strength! Repent, we should offer happiness if never totally we hear anywhere. The media, culture, and world crimes as drugs are all about him, and he remains patient as he is. To this I humble wife, that her boys will be included when it will take the number of children down the road that leads them to Father and
# As a disciple of Jesus Christ, I testify with my grief and deep despair that there may be one soul unto me that which I tarry." (Revelation 18:7).
#  President John Taylor, speaking to the Corinthians, taught through revelation that with faith on the one hand of God they might be washed and cleansed from all their sins, and should receive the Holy Ghost, which he instituted by the laying on of hands by those who are covenant to follow the Lord and have required covenants. But some blessing the faithful will often receive from a
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 208/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 207
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - loss: 0.0885
# finished training...
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, clearly, get more and more bold than we can experience the same thoughts that come into societies or traditions. I invite you to consider the Lord’s standards for support and direct them in their preparation.
#  The Doctrine and Covenants gives this example:
#  "Let all men beware how they
# As a disciple of Jesus Christ, I testify that God speaks today through His chosen servants in The Church of Jesus Christ of Latter-day Saints. Thomas S. Monson is God’s prophet. Our Heavenly Father and His Son, Jesus Christ, live in power as order from the journey home (.
#  We have been taught with powerful and instructive speakers as they were taught by the Savior. Both then and now the three of the twelve great multitude … are blessed by reason of their ways, and their works shall follow him;
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, clearly, get back on course. We can!
#  All our footsteps on Him will be without pleasure. If, in honest and delicate circumstances, we expect to be rescued privately and quickly, being beaten toward temptation and, like an old star, followed John the Sabbath. We are asked
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. The Lord instructed Emma to expound the scriptures, to exhort the Church, to receive the Holy Ghost, and to spend her time "learning much." Leave the past to share the love which came those days ago and their previous habits emphasize empty technology and the internet, social media, and other family circumstances. We should build on the personal and constant and enduring purpose of our
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, measured by the many names previously before us in our day, try right, for God has helped us "truly to love one another" (Heb. 11:25), as Nephi declares: "All men, everywhere, … must take place in sorrows."
#  Then he said to the dead in
# As a disciple of Jesus Christ, I testify of the truth of these things. In the name of Jesus Christ, amen.
#
#  Our purpose is to balance the Church and the home experiences in a way that will greatly increase faith and spirituality and deepen conversion.
#  As President Russell M. Nelson has just beautifully and story as one of many centuries after its dedication, began the translation of the standard works by which the Lord had their day and his heroic service intimately than to a university education. Plans were announced at one facility church,
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 209/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 208
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 225ms/step - loss: 0.0824
# finished training...
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, measured by the many names previously before us in our day, try right, for God has helped us "truly to do" (Mosiah 4:11). The heavenly gift of enduring chastening can discern otherwise. A friend of many years told me a tender scene of a friend who recently returned from
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, clearly, get more and more bold than we can experience the same thoughts that come into societies or traditions. I invite you to consider the Lord’s standards for support and direct them in their preparation.
#  The Doctrine and Covenants gives this example:
#  "Let all men beware how they
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On, following the principle, the Holy Bible gives abundant answers. After the phrase, Alma stated, "And now, my beloved brethren, I say unto you that if ye will enter in by the way, and receive the Holy Ghost, it will show unto you all things what ye should do" (2 Nephi 32:5). Through the constant companionship of the Holy Ghost, every member of the
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, clearly, get more and more bold than we can experience the same thoughts that come into societies or traditions. I invite you to consider the Lord’s standards for support and direct them in their preparation.
#  The Doctrine and Covenants gives this example:
#  "Let all men beware how they
# As a disciple of Jesus Christ, I testify to you that our wondrous perspective and trust in God always bless us with healing in the world.
#  The temple is another holy place specifically set apart for worshipping and serving God and learning eternal truths. We consider the importance of keeping our standards. In the Book of Mormon, Alma helps us understand patience. After telling about this danger, Joseph Smith was no different teacher than I was in the military. So maybe I could have given them a spiritual experience. I did not know what to
# As a disciple of Jesus Christ, I testify to you that our wondrous perspective and trust in God always bless us with the importance of the ordinances of God.
#  Teaching in the home is becoming a primary priority that our our youth members do not have to be touched by the Spirit, but obedience never to greater faith in Him.
#  Every one of us is called by his own name, calling us by teaching and rearing them in the Lord’s way to love and care for their own wife and children. There is no better setting but to avoid
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 210/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 209
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - loss: 0.0744
# finished training...
# As a disciple of Jesus Christ, I testify to you that our wondrous perspective and trust in God always bless us with healing in the world.
#  The temple is another holy place specifically set apart for worshipping and serving God and learning eternal truths. We think, act, and dress differently in the house of the Lord from any other places that we may frequent. In His holy house, if we will, we can be still and know that God is our Heavenly Father, we are His children, and Jesus Christ is our Savior.
#
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, measured by the many names previously before us in our day, try right, for God has helped us "truly to do" (Mosiah 4:11). The heavenly gift of enduring chastening can discern otherwise. A powerful body is an act of rebellion that "bringeth them pure unto [the] Lord
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, clearly, get more and more humble to our eternal home.
#  In recent years there has been a significant era in the history of the Church. We have heard men’s messages are more than a spiritual experience under For the Savior’s Second Coming provides added effect to all of our activity
# As a disciple of Jesus Christ, I testify to you that our wondrous perspective and trust in God always bless us in our respective ways.
#  In recent months President Gordon B. Hinckley has called on us to hold our people close to the Church, to carry on the many callings that are sacred and effective in their place.
#  A giant interrupted by thoughts of youth, Brigham Young had a similar experience for our Lord and Savior, Jesus Christ. Our personal covenant with Him, the Lord also sends Comforter, the Holy Spirit
# As a disciple of Jesus Christ, I testify that "peaceable followers of Christ" will find personal peace in this life and a glorious heavenly reunion. I bear a sure witness of the Savior’s divinity and the reality of His Atonement. He is our Savior and Redeemer. In the name of Jesus Christ, amen.
#
#  We truly are called His servants! We are what we know, we respect Him as our Savior, including His earthly ministry, and that must be moved us back to Him.
#  After the great Fall, the
# As a disciple of Jesus Christ, I testify to you that our wondrous perspective and trust in God always bless us in our respective ways.
#  In recent months President Gordon B. Hinckley has called on us to hold our people close to the Church, especially the newly converted member. Yet President Russell M. Nelson has urged us to "expand our circle of love to embrace the whole human family."
#  An individual who accepts the Savior and His Church takes our lots of heaven. I have heard King Benjamin declare that he had
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 211/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 210
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - loss: 0.0699
# finished training...
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we can, clearly, get more and more humble to our eternal home.
#  As you are valiant in the faith in the Savior, desire to be worthy, and spiritual strength will increase. I so testify in the sacred name of the Lord Jesus Christ, amen.
#
#  Meekness is a
# As a disciple of Jesus Christ, I testify to you that our wondrous perspective and trust in God always bless us with the importance of the ordinances of God.
#  Children are the absolute choice to avoid the sins of immorality and personally carry burdens that can be ignored or forgotten. When attitudes or priorities are harder or less important, too sacred to make it special, we commit our potential to live His gospel and be prepared to "search diligently, that ye may know with a surety that I have called you out in this Jesus Christ: for ye are
# As a disciple of Jesus Christ, I testify with my grief and anguish in my heart. I have prophesied that I have been surrounded by many hands of angels that I shall never forget the testimony I have of the nearly 50 years since my calendar was more than my being seen by me. I was in the hundreds never left to go out to meet Him, to understand His Father as the Son of God. As we follow Him, He blesses us with gifts, talents, and the strength to do His will, allowing us to go
# As a disciple of Jesus Christ, I testify to you that our wondrous perspective and trust in God always bless us in our respective ways.
#  In recent years there will be a few temple experiences with our Heavenly Father because we may behold thousands of good people who attend calls or act with painful attention to the counsel of a loving parent, parents, or family friend. As powerful as I can think of that experience, I can still taste the soap. The lesson was worthwhile. I think I can honestly say that I is asking you to do
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness that we do more than anything else we will ever know.
#  This sacred time of tender celebrations also brings release when granite and storm claims a drop from which each hall be done.
#  The missionaries could not sing "I Am a Child of God" with reference to our stewardship, lightning, [and
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Savior and Mediator. Revelation is real. The fulness of the gospel has been restored to the earth in this dispensation. I so testify in the sacred name of the Lord Jesus Christ, amen.
#
#  It is wonderful to have older men of great spiritual maturity and judgment serving in the senior leadership positions of the restored Church of Jesus Christ.
#  In 1833 the Prophet Joseph
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 212/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 211
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - loss: 0.0650
# finished training...
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness and promise we can not only know about the Lord but also come to know Him as we exercise faith in, follow, serve, and believe Him. I so testify in the sacred name of Jesus Christ, amen.
#
#  A spiritual early warning system … can help parents in Zion to be
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness and promise we can not only know about the Lord but also come to know Him as we exercise faith in, follow, serve, and believe Him. I so testify in the sacred name of Jesus Christ, amen.
#
#  In the strength of the Lord we can do and endure and overcome
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness and promise we can not only know about the Lord but also come to know Him as we exercise faith in, follow, serve, and believe Him. I so testify in the sacred name of Jesus Christ, amen.
#
#  A spiritual early warning system … can help parents in Zion to be
# As a disciple of Jesus Christ, I testify that God lives! Jesus is the Christ! His Church has been restored to the earth! God’s prophet upon the earth today is President Thomas S. Monson, whom I sustain with all my heart. I so testify, with my expression of love and blessing for each of you, in the sacred name of Jesus Christ, amen.
#
#  The Tabernacle is filled to capacity. To them we gladly recognize and appreciate the inspired guidance from the Spirit. This is His work. We shall
# As a disciple of Jesus Christ, I testify with my heart and soul that I was called a new General Authority.
#  Years later, President Heber J. Grant issued a clarion call for "men of mature years and sound judgment, who are the parents of six." The Savior will not only consecrate our afflictions for our gain, but He will use the unfairness for our benefit. In time, He has declared: "I, the Lord, am merciful and gracious unto those who fear me, and delight to honor those who serve me in righteousness
# As a disciple of Jesus Christ, I testify that "peaceable followers of Christ" will find personal peace in this life and a glorious heavenly reunion. I bear a sure witness of the Savior’s divinity and the reality of His Atonement. He is our Savior and Redeemer. In the name of Jesus Christ, amen.
#
#  An assignment in a priesthood quorum in San Francisco was called "wards and stakes" in the Church [and His] household."
#  This commandment has never been claimed to be cause. If we let God prevail in
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 213/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 212
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 232ms/step - loss: 0.0608
# finished training...
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ.
#  How are we to respond to our changing world? While some are neglecting their faith, others are searching for the truth. We have taken upon ourselves the name of the Savior. What more are we to do?
#  In justice, be hoped for when something starts to be felt.
#  We as members of this Church cannot have something to measure your standing, by the responsibility that is in you
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ.
#  How are we to respond to our changing world? While some are neglecting their faith, others are searching for the truth. We have taken upon ourselves the name of the Savior. What more are we to do?
#  Over time, the gospel, and whatever principle you can enter into in life, couldn’t have find any more faith in the Savior and an increase of love toward those who seems to do
# As a disciple of Jesus Christ, I testify with my heart and soul that I was called a new General Authority.
#  Years later, President Gordon B. Hinckley made the historic announcement the choir was beginning to sing "The Spirit of God like a fire is burning!" (Hymns, 1985, no. 2). As we sang together, the Spirit of the Lord descended upon us, and we were made ready for prayer. Our sacred music is a powerful preparation for prayer and gospel teaching.
#  We need to make more use of our
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness and promise we can not only know about the Lord but also come to know Him as we exercise faith in, follow, serve, and believe Him. I so testify in the sacred name of Jesus Christ, amen.
#
#  Of the Quorum of the Twelve Apostles
#  A gospel principle
# As a disciple of Jesus Christ, I testify and testify that the work of Jesus Christ is true. I know He lives. I promise that if you and those you love will seek Him in all humility, sincerity, and diligence, you will know with a surety too. Your witness will come. And the very joy the Lord offers to the faithful.
#  This past month, a very lengthy meeting is conducted with great appreciation. Tears of gratitude came not only to the Priesthood of The Church of Jesus Christ of Latter-day Saints alone
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know Him and the Father and Jesus Christ and be true to His work.
#  Our lives are touched by the words of the Savior in the Sermon on the Mount: "And we talk of Christ, we rejoice in Christ, we preach of Christ, we prophesy of Christ, … that our children may know to what source they may look for a
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 214/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 213
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - loss: 0.0574
# finished training...
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ.
#  How are we to respond to our changing world? While some are neglecting their faith, others are searching for the truth. We have taken upon ourselves the name of the Savior. What more are we to do?
#  Over time, many of you have been absolutely loyal to the Church and its leaders and claim "the end of your salvation, doing all things with prayer and thanksgiving, that ye may
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness and promise we can not only know about the Lord but also come to know Him as we exercise faith in, follow, serve, and believe Him. I so testify in the sacred name of Jesus Christ, amen.
#
#  In the strength of the Lord we can do and endure and overcome
# As a disciple of Jesus Christ, I testify to you that our wondrous perspective and trust in God always bless us with the importance of mortality. Those Saints who love and honor the priesthood promise receive from him, remembering them, "Truth no more" (John 3:5) when He said:
#  "If any man will come after me, let him deny himself, and take up his cross, and follow me.
#  "For whosoever will save his life shall lose it: and whosoever will lose his life for my sake shall find it.
#  "For what is
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ.
#  How are we to respond to our changing world? While some are neglecting their faith, others are searching for the truth. We have taken upon ourselves the name of the Savior. What more are we to do?
#  In justice, be hoped for when something starts to be felt.12
#  As I have reflected on gifts from our Heavenly Father and from Jesus Christ, I have come
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness and promise we can not only know about the Lord but also come to know Him as we exercise faith in, follow, serve, and believe Him. I so testify in the sacred name of Jesus Christ, amen.
#
#  Of the Quorum of the Twelve Apostles
#  Covenants and ordinances
# As a disciple of Jesus Christ, I testify and testify that the work of Jesus Christ is true and honored in my prayer.
#  Upon all my life, there has come an essence of an extent I have felt in the seasoned contributions of priesthood quorums. As a result, I occupy two simple suggestions in greater priesthood responsibility. Please listen carefully. "The Book of Mormon is an endless treasure of wisdom and inspiration, and, of course, a book about a civilization limit from a temple in the tiny town on the Pacific. She got off the
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 215/250
# File 'speakers/david-a-bednar.txt' found locally. Using it.
# Using sequence length: 256 for epoch 214
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - loss: 0.0552
# finished training...
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness and promise we can not only know about the Lord but also come to know Him as we exercise faith in, follow, serve, and believe Him. I so testify in the sacred name of Jesus Christ, amen.
#
#  A spiritual early warning system … can help parents in Zion to be
# As a disciple of Jesus Christ, I testify that the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On that blessed day, we will know He knows each of us by name. And I witness and promise we can not only know about the Lord but also come to know Him as we exercise faith in, follow, serve, and believe Him. I so testify in the sacred name of Jesus Christ, amen.
#
#  A spiritual early warning system … can help parents in Zion to be
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father lives and loves each of us and that Jesus is the Christ, our Lord and Savior. I testify that through The Church of Jesus Christ of Latter-day Saints is restored through the Prophet Joseph Smith, "a manifestation of the Holy Ghost bearing witness of the divine nature of the family" (in Conference Report, Apr. 1998, 43; or Ensign, May 1998, 34). This distinctive influence of the Holy Ghost draws people to identify,
# ...
# As a disciple of Jesus Christ, I testify to you that our Savior lives, that through Him all men will are called to serve. He has done so from the beginning and declared that He will come again to earth forever. This gift, simple as God’s holy scriptures, has clearly spoke, is applicable thus, like virtue, as science help, race, or language. We cannot become involved without independent action to decide which is contrary to our challenge or try to express our sacramental service do indeed find a place to establish membership so rapidly, and fortunately across the
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, because the day will come when every knee shall bow, and every tongue confess that Jesus is the Christ; and salvation just constitutes the Fall of a well-boy Apostle, Heber J. Grant! Now, after your initial concern, we need more interviews. I "set a track in the home." He then said, "You don’t know how much you think they can get started."
#  You young women holding a special love touch lives.
# As a disciple of Jesus Christ, I testify to you that our love of and eternal joy is ours and kingdom. Our desire is to be more profitable servants in the Lord’s vineyard. We can let God prevail in our lives, or not.
#  As we return to our homes and to our daily activities, let us contemplate the purposes which will be for our redemption. Surely we can take President into the fold of God, that they may touch the lives of all those about God and love of our fellowman. That feeling of terrible heat and wonder
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, and he loves you with an infinite love.
#  My dear brethren and sisters, not many young people of the Church long after their release as a stake president. These are the exact words that touch the feeling of others of me. The song of the righteous is a prayer unto the Lord (see D&C 59:21).
#  If I had expected you to remain, prepared, and welcomed to live with you, then keep the boys handle
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 247/250
# File 'speakers/patrick-kearon.txt' found locally. Using it.
# Using sequence length: 256 for epoch 246
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0210
# finished training...
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, because the day will come when every knee shall bow and every tongue confess that Jesus is the Christ. Though we may have the benefits and timing, resulting from change, we do have done wrong and cannot be changed. We must never lose sight of the fact that we are Church because we love the Lord Jesus Christ. We go to word to wife. If it were possible for me how good you were, following this situation, I
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, because the day will come when every knee shall bow and every tongue confess that Jesus is the Christ. Though we may have received Christ and are willing to take upon us the name of Christ when we obey the commandments of the Lord and remember his counsel in how we bless them, we must not take that same kind of trust or where things others may say cannot be held here. I know it was His will. I saw new
# As a disciple of Jesus Christ, I testify to you that our love of and eternal joy is evident in the revealed purposes of the Salt Lake Temple when He walked in His majesty and power. His physical condition was not limited by national or political boundaries, but we can truly remember our Savior and Redeemer, that Joseph Smith is a prophet of God, that he held a university and invited me to assist in this marvelous work together.
#  May every widow’s friend of mine knew I was in trouble. If my boy was around nine years
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, because the day will come when every knee will bow and every tongue confess that Jesus is the Christ. On, Jesus Christ is the Savior of the world. He is the Redeemer of the world. We are His humble servants. We know Them.
#  We pray to everyone who inspired correction and regret that can be mean only after we have nourished ourselves and steal a good word to other churches or professionals.
#  This year we
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, because the day will come when every knee shall bow and every tongue confess that Jesus is the Christ and that this people might not suffer and die. Who would want to point away the suffering caused by the counsel he used as a "new golden branch after the sun brought them together, in [no Christian] living."
#  An understanding of God’s great plan of happiness, however, has promised eternal life as our Heavenly Father so that we might
# As a disciple of Jesus Christ, I testify to you that our Savior lives, that he was born of a divine rescue man, falsely accused, and supposed that he should preach these words. Were he not able to give whatever ordinance is desirable … we must become man-made and is greater than the single good news!
#  Hence, said the Prophet Joseph Smith "laid … out among the people of his ward have these same responsibilities in the cause of the Holy One of Israel" (Acts 9:9).
#  From the islands of the Pacific
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 248/250
# File 'speakers/patrick-kearon.txt' found locally. Using it.
# Using sequence length: 256 for epoch 247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0192
# finished training...
# As a disciple of Jesus Christ, I testify to you that our Savior lives, that through Him all men will are called to serve. He calls you and me to participate in any form of evil in the world today. Also, we need to make a little more effort to assist our children and grandchildren with their arms and hearts. We honor more concerned He would violate a trust which is taught by their mothers. Thus, peer pressure leads to little so-called criticism to those in the we express admiration to those who have lost precious companionship, in the
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, because the day will come when every knee will bow and every tongue confess that Jesus is the Christ. Though we may have the benefits of the dispensations, the soldiers of the nine great King Solomon died by the Lamb of God. Many similar revelations have been spoken of as members of the Quorum of the Twelve on April 6, 1830. And not all my disciples received in the upper room of the temple directly, she was greeted
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, because the day will come when every knee will bow and every tongue confess that Jesus is the Christ. Though we may have lost ourselves in loneliness, we are reluctant to take this miracle for our sakes. When we see God working through us to keep His commandments, we can access His power, and be most supportive. As members of the Church, we are encouraged to help collect family strong enough to help us better understand them. Just
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, how much he loves him and makes a difference in the hearts of Rebecca and Sister Brown Mercy. One declared love cradled in the sepulchre to closed and could not sleep. This so reaching By threat and authority to bring about the gathering of Israel in preparation for the Second Coming of the Savior.
#  Scriptures identify other important traditions: "Wherefore, if ye shall press forward [that which is good, or sufficient for the knowledge of the
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, because the day will come when every knee will bow and every tongue confess that Jesus is the Christ. Though we may have the benefits and timing, resulting from change, we do have done wrong and cannot be changed. We must put aside our pride and thoughts of past adversity. May we fill our homes with love, with appreciation, with respect, with full purpose of our earnest faith, in the strength of the gospel, you will find that the still
# As a disciple of Jesus Christ, I testify to you that our love of and faith that the Savior loves each of us is our own reality.
#  This requirement also pertains to our ancestors. Paul taught "that they without us should not be made perfect." Again, in that verse in 1987, The Elders Spencer W. Kimball and Legrand Richards, Jr. Elder Mark E. Petersen, Presiding Bishop of the Western Hemisphere Church and His Apostles, said this:
#  "I have sympathy for young men to listen to and
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 249/250
# File 'speakers/patrick-kearon.txt' found locally. Using it.
# Using sequence length: 256 for epoch 248
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0184
# finished training...
# As a disciple of Jesus Christ, I testify to you that our Savior lives, that through Him all men will are redeemed.
#  The law of the gospel is God’s creation. His authority is required for the salvation of the obedient. This authority is the major task of such action.
#  The Lord’s storehouse includes the time, talents, skills, compassion, consecrated material, and financial means of faithful elders and sisters.
#  The distance and progress at an ever-increasing pace requires many more nourishing gospel terms of service. I quote a report or popular prayer, which
# As a disciple of Jesus Christ, I testify to you that our Savior lives, that through Him all men will are called to serve. He calls you and me to participate in any form of evil in the world today. Contemplation will nurture from scripture study. You may have been more important to you wherever you are pursuing your responsibilities. I bear witness that the Lord lives. He loves you and will help you make good choices, as you pray for His help.
#  A truth of the adage "Having a perfect man is not to give in
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, because the day will come when every knee will bow and every tongue confess that Jesus is the Christ. Though we may have lost ourselves in loneliness, we are reluctant to take this miracle for our sakes. When we see God working through us and with us, may we be worthy recipients of the divine power of the priesthood of God. We must not only cast their hearts than hear, this nation did not know the change.
#  As they
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, because the day will come when every knee shall bow and every tongue confess that Jesus is the Christ. Though we may have lost ourselves in loneliness, we are reluctant to take this miracle for our sakes. When we see God working through us and with us, may we be encouraged, even grateful for that answer to our mothers and our fathers. An individual must make choices to act the Lord’s way would create. Our task was simple, however
# As a disciple of Jesus Christ, I testify to you that our Savior lives, that through Him all men will are redeemed.
#  The reality of such cautions is everlasting in purpose. Human plan is created to deal with the terrible losses of leadership in their country and the temple.
#  Some members struggle with faith and hope for fun and escape the head of a missionary rather than the meaning of divine authority: "He that believeth on me, the people of the poor and the weary been praying, and know that my Father sent me.
#  "And my
# As a disciple of Jesus Christ, I testify to you that our Savior lives, that he was born of Mary of Nazareth, Heavenly Father, had entrusted to Joseph the keys to direct the Church of Jesus Christ. How grateful I was that my funeral plan did not change. But as I prayed, I heard Mrs. I know that was Boy Scouts and Gentiles of the Lord."
#  But the young woman had forgiven her to know that the "testimony of the Apostles and prophets [would] be the kingdom of God"
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch: 250/250
# File 'speakers/patrick-kearon.txt' found locally. Using it.
# Using sequence length: 256 for epoch 249
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0185
# finished training...
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, because the day will come when every knee will bow and every tongue confess that Jesus is the Christ. Though we may have the benefits of the dispensations, with the records and the finest operation, this is a letter uttered by a woman who indicates that all who have heard them may be safely covered and are going to die."
#  Dear brothers and sisters, the difference between happiness and misery … often comes down to an error of little way that
# As a disciple of Jesus Christ, I testify to you that our Heavenly Father loves you like a son, because the day will come when every knee will bow and every tongue confess that Jesus is the Christ. Though we may have the benefits of the dispensations, with the aid of means not only do His spiritually self-centered Plan for His children, but central to all this, there are times and greater blessings to us is the miraculous blessing we can seek once more in order for divine intervention. It is possible because we begin by beginning. We
# As a disciple of Jesus Christ, I testify to you that our Savior lives, that through Him all men will are called to serve. He calls you and me to participate with Him and ask for His blessings and sharing it this day. I express my personal gratitude for the privilege to address you, and it can be appropriate to communicate with you, as I have sung and convinced you they have been prompted to look for and extend to you what great potential transcends … you and your future efforts forever as sacred nature of your work.
#  This summer
# As a disciple of Jesus Christ, I testify to you that our time had not been fully written, and I was told to use this impression: why did he not take the advantage of failing to repay what the Prophet Joseph spoke when he felt the importance of hope: "A little child shall lead them. … And by this same day all things are possible to him that believeth." (Mark 9:23.)
#  Are we our brother’s keeper? Are we willing to pray? The scriptures teach that we are all more of Israel than are we going
# As a disciple of Jesus Christ, I testify to you that our Savior lives. He directs His Church to all the lives He has prepared under "a living testimony, and a stunning soul is truly somewhat overwhelming; therefore, lust and pride have no root in good things to come, nor can we express our feelings of self-centered relationship with ourselves.
#  "With a strong father and a successful husband and a man knew the right of worship, repentance of things divine. He inspired the multitude to endure to the end.
#  Peace comes from knowing that the
# As a disciple of Jesus Christ, I testify to you that our Savior lives, that he was born of a divine rescue man, is divinely ordained of His Church. Together we worship Him. It is in the Church in unprecedented numbers. It is expected that these young men and women will meet ourselves here in the Conference Center or attend or listened to inspired messages. Beyond parting on the Internet, where one can get employment when it looks so beautiful that we, except we succeed in blessing what may be done without argument, deny the glory of
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# Final epoch (250) reached.
# Model saved as models/conf-t4-200e_curric_kearon-t1-50e.keras

# %%
model.load_weights("models/conf-t4-200e.keras")
for temp in [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]:
    produce_sample(model, vectorize_layer, vocabulary, temp, num_epochs_total - 1, 'What does the fox say?')

# %%
final_seed_text = "The world seemed like such a peaceful place until the tree of life was discovered in London."
model_path = 'models/'
response_path = 'saved_files/responses/'

base_filename = f'conf-t{main_test_num}-{base_epochs}e_{learn_type}'
speaker_file_end = f'-t{transfer_test_num}-{transfer_epochs}e'

keras_ext = '.keras'
response_ext = '.txt'

# %%
def save_responses(model_file, response_file, seed_text):
    model.load_weights(model_file)
    for temp in [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]:
        response = \
            produce_sample(model,
                vectorize_layer,
                vocabulary,
                temp,
                num_epochs_total - 1,
                seed_text,
                length=1000,
                do_print=False)
        with open(response_file, 'a') as f:
            f.write(f"Temp: {temp}\n")
            f.write(response)
            f.write('\n\n')
    print(f"Response saved as {response_file}")

# %%
for speaker in speakers:
    last_name = '_' + speaker.split('-')[-1]
    speaker_keras_filename = model_path + base_filename + last_name + speaker_file_end + keras_ext
    speaker_response_filename = response_path + base_filename + last_name + speaker_file_end + response_ext
    save_responses(speaker_keras_filename, speaker_response_filename, final_seed_text)
# Out:
# /home/tman/tf-env/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 34 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Response saved as saved_files/responses/saved_files/responses/conf-t4-200e_curric_bednar-t1-50e.txt
# Response saved as saved_files/responses/saved_files/responses/conf-t4-200e_curric_uchtdorf-t1-50e.txt
# Response saved as saved_files/responses/saved_files/responses/conf-t4-200e_curric_holland-t1-50e.txt
# Response saved as saved_files/responses/saved_files/responses/conf-t4-200e_curric_nelson-t1-50e.txt
# Response saved as saved_files/responses/saved_files/responses/conf-t4-200e_curric_monson-t1-50e.txt
# Response saved as saved_files/responses/saved_files/responses/conf-t4-200e_curric_kearon-t1-50e.txt

# %%
general_keras_filename = model_path + base_filename + keras_ext
general_response_filename = response_path + base_filename + response_ext
save_responses(general_keras_filename, general_response_filename, final_seed_text)
# Out:
# Response saved as saved_files/responses/saved_files/responses/conf-t4-200e_curric.txt
